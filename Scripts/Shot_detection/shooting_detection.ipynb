# %%
import cv2
import os
import ultralytics
from ultralytics import YOLO
import mediapipe as mp
import xml.etree.ElementTree as ET

# %%
# # Get the versions
# opencv_version = cv2.__version__
# ultralytics_version = ultralytics.__version__
# mediapipe_version = mp.__version__

# # Write the versions to a requirements.txt file
# with open('/content/drive/MyDrive/bollogy/requirements.txt', 'w') as f:
#     f.write(f"opencv-python=={opencv_version}\n")
#     f.write(f"ultralytics=={ultralytics_version}\n")
#     f.write(f"mediapipe=={mediapipe_version}\n")
#     f.close()

# print("requirements.txt file has been created with the following content:")
# print(f"opencv-python=={opencv_version}")
# print(f"ultralytics=={ultralytics_version}")
# print(f"mediapipe=={mediapipe_version}")

# %%
# Load YOLOv8 model
model_path = 'yolov8n.pt'  # Using a pre-trained YOLOv8 model
model = YOLO(model_path)

# Initialize MediaPipe Pose
mp_pose = mp.solutions.pose
pose = mp_pose.Pose(static_image_mode=True, model_complexity=2, enable_segmentation=False, min_detection_confidence=0.5)

# %%
# Directory to save results
bbox_output_dir = 'Output/Detected_bbox'
Handsup_output_dir = 'Output/Hands_Up/'
xml_dir = 'Output/XML_Files'
os.makedirs(Handsup_output_dir, exist_ok=True)
os.makedirs(xml_dir, exist_ok=True)

# Confidence threshold
confidence_threshold = 0.5

# %%
def get_pose_landmarks(image):
    results = pose.process(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    if results.pose_landmarks:
        keypoints = [landmark for landmark in results.pose_landmarks.landmark if landmark.visibility > confidence_threshold]
        if len(keypoints) > len(results.pose_landmarks.landmark) / 2:
            return results.pose_landmarks
    return None

# %%
def classify_pose(landmarks):
    if not landmarks:
        return "No pose detected"

    landmarks_list = [landmark for landmark in landmarks.landmark]

    left_wrist = landmarks_list[mp_pose.PoseLandmark.LEFT_WRIST.value]
    right_wrist = landmarks_list[mp_pose.PoseLandmark.RIGHT_WRIST.value]
    left_eye = landmarks_list[mp_pose.PoseLandmark.LEFT_EYE.value]
    right_eye = landmarks_list[mp_pose.PoseLandmark.RIGHT_EYE.value]
    nose = landmarks_list[mp_pose.PoseLandmark.NOSE.value]

    # Check if either wrist is above the eyes or nose
    if (left_wrist.y < left_eye.y or left_wrist.y < nose.y) and (right_wrist.y < right_eye.y or right_wrist.y < nose.y):
        return "Hands Up"
    else:
        return "Other Pose"

# %%
def create_xml_for_bounding_box(bounding_box, file_name, save_directory):
    """
    Create an XML file for a given bounding box and file name, and save it to the specified directory.

    Parameters:
    bounding_box (tuple): A tuple containing (xmin, ymin, xmax, ymax).
    file_name (str): The name of the file (without extension).
    save_directory (str): The directory where the XML file will be saved.

    Returns:
    str: The name of the created XML file.
    """
    # Ensure the save directory exists
    os.makedirs(save_directory, exist_ok=True)

    # Define the root element
    annotation = ET.Element('annotation')

    # Define the folder element
    folder = ET.SubElement(annotation, 'folder')
    folder.text = 'images'

    # Define the filename element
    filename = ET.SubElement(annotation, 'filename')
    filename.text = f"{file_name}.jpg"

    # Define the path element
    path = ET.SubElement(annotation, 'path')
    path.text = os.path.join('Output\XML_Files', f"{file_name}.jpg")

    # Define the source element
    source = ET.SubElement(annotation, 'source')
    database = ET.SubElement(source, 'database')
    database.text = 'Unknown'

    # Define the size element
    size = ET.SubElement(annotation, 'size')
    width = ET.SubElement(size, 'width')
    width.text = '1280'  # Placeholder value
    height = ET.SubElement(size, 'height')
    height.text = '720'  # Placeholder value
    depth = ET.SubElement(size, 'depth')
    depth.text = '3'  # Assuming RGB images

    # Define the segmented element
    segmented = ET.SubElement(annotation, 'segmented')
    segmented.text = '0'

    # Define the object element
    obj = ET.SubElement(annotation, 'object')
    name = ET.SubElement(obj, 'name')
    name.text = 'shooting player'
    pose = ET.SubElement(obj, 'pose')
    pose.text = 'Unspecified'
    truncated = ET.SubElement(obj, 'truncated')
    truncated.text = '0'
    difficult = ET.SubElement(obj, 'difficult')
    difficult.text = '0'
    bndbox = ET.SubElement(obj, 'bndbox')
    xmin = ET.SubElement(bndbox, 'xmin')
    xmin.text = str(int(bounding_box[0]))
    ymin = ET.SubElement(bndbox, 'ymin')
    ymin.text = str(int(bounding_box[1]))
    xmax = ET.SubElement(bndbox, 'xmax')
    xmax.text = str(int(bounding_box[2]))
    ymax = ET.SubElement(bndbox, 'ymax')
    ymax.text = str(int(bounding_box[3]))

    # Convert the tree to a string and write it to a file
    tree = ET.ElementTree(annotation)
    xml_file_name = os.path.join(save_directory, f"{file_name}.xml")
    tree.write(xml_file_name)

# %%
def detect_person(model, frame):
    results = model.predict(frame)
    detected_persons = []

    for result in results:
        boxes = result.boxes.xyxy.cpu().numpy()
        scores = result.boxes.conf.cpu().numpy()
        class_ids = result.boxes.cls.cpu().numpy()

        for box, score, class_id in zip(boxes, scores, class_ids):
            if class_id == 0 and score > confidence_threshold:  # Class 0 is 'person' in COCO dataset
                x1, y1, x2, y2 = map(int, box)
                height = y2 - y1
                width = x2 - x1
                center_x = (x1 + x2) // 2
                x1 = center_x - height // 2
                x2 = center_x + height // 2
                x1 = max(0, x1)
                x2 = min(frame.shape[1], x2)
                cropped_person = frame[y1:y2, x1:x2]
                landmarks = get_pose_landmarks(cropped_person)
                pose_label = classify_pose(landmarks)
                if pose_label == "Hands Up":
                    print('Hands UP')
                    detected_persons.append((box, score, class_id, pose_label))
    return detected_persons

# %%
def generate_random_name(length=8):
    """Generate a random string of letters and digits."""
    chars = string.ascii_letters + string.digits
    return ''.join(random.choice(chars) for _ in range(length))

# %%
# Process each video
video_dir = 'Videos_data'  # Update with video path
frame_counter = 0
count=0
for video_file in os.listdir(video_dir):
    if video_file.endswith('.mp4'):
        video_path = os.path.join(video_dir, video_file)
        cap = cv2.VideoCapture(video_path)

        while cap.isOpened():
            ret, frame = cap.read()
            if not ret:
                break
            count+=1
            detected_persons = detect_person(model, frame)

            for box, score, class_id, pose_label in detected_persons:
                
                file_name = f'{generate_random_name()}.jpg'
                file_path = os.path.join(Handsup_output_dir,file_name)
                cv2.imwrite(file_path, frame)
                
                x1, y1, x2, y2 = map(int, box)
                cv2.rectangle(frame, (x1, y1), (x2, y2), (255, 0, 0), 2)
                image_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
                bbox_file_path = os.path.join(bbox_output_dir, file_name)
                cv2.imwrite(bbox_file_path, image_rgb)

                # create_pascal_voc_annotation(file_name, frame.shape, bounding_boxes, xml_dir)
                create_xml_for_bounding_box(box, file_name.replace('.jpg', ''), xml_dir)
                frame_counter += 1
            print(count)
        cap.release()
# Out:
# 0: 384x640 4 persons, 296.8ms
# Speed: 11.0ms preprocess, 296.8ms inference, 20.0ms postprocess per image at shape (1, 3, 384, 640)
# 1
# C:\Users\ali.mohsin\AppData\Local\anaconda3\Lib\site-packages\google\protobuf\symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# 0: 384x640 5 persons, 192.0ms
# Speed: 3.0ms preprocess, 192.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 2
#
# 0: 384x640 5 persons, 184.0ms
# Speed: 3.0ms preprocess, 184.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 3
#
# 0: 384x640 4 persons, 181.0ms
# Speed: 4.0ms preprocess, 181.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 4
#
# 0: 384x640 4 persons, 179.0ms
# Speed: 3.0ms preprocess, 179.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 5
#
# 0: 384x640 4 persons, 176.0ms
# Speed: 3.0ms preprocess, 176.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 6
#
# 0: 384x640 3 persons, 182.0ms
# Speed: 3.0ms preprocess, 182.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 7
#
# 0: 384x640 4 persons, 179.0ms
# Speed: 3.0ms preprocess, 179.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 8
#
# 0: 384x640 3 persons, 178.0ms
# Speed: 3.0ms preprocess, 178.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 9
#
# 0: 384x640 3 persons, 180.0ms
# Speed: 3.0ms preprocess, 180.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 10
#
# 0: 384x640 3 persons, 196.0ms
# Speed: 5.0ms preprocess, 196.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 11
#
# 0: 384x640 3 persons, 185.0ms
# Speed: 3.0ms preprocess, 185.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 12
#
# 0: 384x640 3 persons, 181.0ms
# Speed: 3.0ms preprocess, 181.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 13
#
# 0: 384x640 4 persons, 179.0ms
# Speed: 3.0ms preprocess, 179.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 14
#
# 0: 384x640 4 persons, 182.0ms
# Speed: 3.0ms preprocess, 182.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 15
#
# 0: 384x640 4 persons, 181.0ms
# Speed: 3.0ms preprocess, 181.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 16
#
# 0: 384x640 5 persons, 177.0ms
# Speed: 4.0ms preprocess, 177.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 17
#
# 0: 384x640 3 persons, 175.0ms
# Speed: 3.0ms preprocess, 175.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 18
#
# 0: 384x640 3 persons, 174.0ms
# Speed: 3.0ms preprocess, 174.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 19
#
# 0: 384x640 4 persons, 1 skateboard, 180.0ms
# Speed: 3.0ms preprocess, 180.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 20
#
# 0: 384x640 4 persons, 178.0ms
# Speed: 3.0ms preprocess, 178.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 21
#
# 0: 384x640 4 persons, 175.0ms
# Speed: 3.0ms preprocess, 175.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 22
#
# 0: 384x640 4 persons, 185.0ms
# Speed: 3.0ms preprocess, 185.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 23
#
# 0: 384x640 4 persons, 179.0ms
# Speed: 3.0ms preprocess, 179.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 24
#
# 0: 384x640 4 persons, 178.0ms
# Speed: 4.0ms preprocess, 178.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 25
#
# 0: 384x640 5 persons, 204.0ms
# Speed: 4.0ms preprocess, 204.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 26
#
# 0: 384x640 4 persons, 218.0ms
# Speed: 3.0ms preprocess, 218.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 27
#
# 0: 384x640 5 persons, 205.0ms
# Speed: 3.0ms preprocess, 205.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 28
#
# 0: 384x640 6 persons, 179.0ms
# Speed: 3.0ms preprocess, 179.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 29
#
# 0: 384x640 5 persons, 185.0ms
# Speed: 4.0ms preprocess, 185.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 30
#
# 0: 384x640 4 persons, 193.0ms
# Speed: 2.0ms preprocess, 193.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 31
#
# 0: 384x640 6 persons, 178.0ms
# Speed: 3.0ms preprocess, 178.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 32
#
# 0: 384x640 6 persons, 176.0ms
# Speed: 3.0ms preprocess, 176.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 33
#
# 0: 384x640 5 persons, 184.0ms
# Speed: 3.0ms preprocess, 184.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 34
#
# 0: 384x640 5 persons, 178.0ms
# Speed: 2.0ms preprocess, 178.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 35
#
# 0: 384x640 4 persons, 358.0ms
# Speed: 5.0ms preprocess, 358.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
# 36
#
# 0: 384x640 5 persons, 257.0ms
# Speed: 4.0ms preprocess, 257.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 37
#
# 0: 384x640 4 persons, 200.0ms
# Speed: 3.0ms preprocess, 200.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 38
#
# 0: 384x640 6 persons, 204.0ms
# Speed: 4.0ms preprocess, 204.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# 39
#
# 0: 384x640 5 persons, 418.0ms
# Speed: 4.0ms preprocess, 418.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 40
#
# 0: 384x640 4 persons, 237.0ms
# Speed: 4.0ms preprocess, 237.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 41
#
# 0: 384x640 5 persons, 224.0ms
# Speed: 4.0ms preprocess, 224.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 42
#
# 0: 384x640 3 persons, 233.0ms
# Speed: 3.0ms preprocess, 233.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 43
#
# 0: 384x640 4 persons, 216.0ms
# Speed: 3.0ms preprocess, 216.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 44
#
# 0: 384x640 4 persons, 238.0ms
# Speed: 3.0ms preprocess, 238.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 45
#
# 0: 384x640 4 persons, 215.0ms
# Speed: 3.0ms preprocess, 215.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 46
#
# 0: 384x640 5 persons, 340.0ms
# Speed: 4.0ms preprocess, 340.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 47
#
# 0: 384x640 3 persons, 268.0ms
# Speed: 3.0ms preprocess, 268.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# 48
#
# 0: 384x640 5 persons, 212.0ms
# Speed: 3.0ms preprocess, 212.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 49
#
# 0: 384x640 4 persons, 182.0ms
# Speed: 4.0ms preprocess, 182.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 50
#
# 0: 384x640 3 persons, 187.0ms
# Speed: 3.0ms preprocess, 187.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 51
#
# 0: 384x640 3 persons, 179.0ms
# Speed: 2.0ms preprocess, 179.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 52
#
# 0: 384x640 3 persons, 182.0ms
# Speed: 3.0ms preprocess, 182.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 53
#
# 0: 384x640 3 persons, 177.0ms
# Speed: 3.0ms preprocess, 177.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 54
#
# 0: 384x640 3 persons, 265.0ms
# Speed: 3.0ms preprocess, 265.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 55
#
# 0: 384x640 4 persons, 262.0ms
# Speed: 3.0ms preprocess, 262.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 56
#
# 0: 384x640 4 persons, 177.9ms
# Speed: 3.1ms preprocess, 177.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 57
#
# 0: 384x640 4 persons, 177.0ms
# Speed: 3.0ms preprocess, 177.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 58
#
# 0: 384x640 5 persons, 180.0ms
# Speed: 3.0ms preprocess, 180.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 59
#
# 0: 384x640 4 persons, 176.0ms
# Speed: 3.0ms preprocess, 176.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 60
#
# 0: 384x640 5 persons, 1 sports ball, 203.0ms
# Speed: 4.0ms preprocess, 203.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 61
#
# 0: 384x640 5 persons, 1 sports ball, 182.0ms
# Speed: 3.0ms preprocess, 182.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# 62
#
# 0: 384x640 4 persons, 265.0ms
# Speed: 4.0ms preprocess, 265.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# 63
#
# 0: 384x640 4 persons, 322.0ms
# Speed: 4.0ms preprocess, 322.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
# 64
#
# 0: 384x640 4 persons, 338.0ms
# Speed: 7.0ms preprocess, 338.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 65
#
# 0: 384x640 4 persons, 330.0ms
# Speed: 3.0ms preprocess, 330.0ms inference, 10.0ms postprocess per image at shape (1, 3, 384, 640)
# 66
#
# 0: 384x640 4 persons, 202.0ms
# Speed: 5.0ms preprocess, 202.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 67
#
# 0: 384x640 4 persons, 174.0ms
# Speed: 2.9ms preprocess, 174.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 68
#
# 0: 384x640 5 persons, 193.0ms
# Speed: 3.0ms preprocess, 193.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
# 69
#
# 0: 384x640 4 persons, 351.0ms
# Speed: 4.0ms preprocess, 351.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
# 70
#
# 0: 384x640 4 persons, 174.0ms
# Speed: 4.0ms preprocess, 174.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 71
#
# 0: 384x640 5 persons, 176.0ms
# Speed: 3.0ms preprocess, 176.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 72
#
# 0: 384x640 4 persons, 177.0ms
# Speed: 2.0ms preprocess, 177.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 73
#
# 0: 384x640 4 persons, 182.0ms
# Speed: 3.0ms preprocess, 182.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 74
#
# 0: 384x640 4 persons, 194.0ms
# Speed: 2.0ms preprocess, 194.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 75
#
# 0: 384x640 3 persons, 177.0ms
# Speed: 3.0ms preprocess, 177.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 76
#
# 0: 384x640 3 persons, 176.0ms
# Speed: 2.0ms preprocess, 176.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 77
#
# 0: 384x640 5 persons, 180.9ms
# Speed: 3.0ms preprocess, 180.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 78
#
# 0: 384x640 5 persons, 174.0ms
# Speed: 3.0ms preprocess, 174.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 79
#
# 0: 384x640 3 persons, 172.0ms
# Speed: 2.0ms preprocess, 172.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 80
#
# 0: 384x640 3 persons, 188.0ms
# Speed: 3.0ms preprocess, 188.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 81
#
# 0: 384x640 4 persons, 181.0ms
# Speed: 3.0ms preprocess, 181.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 82
#
# 0: 384x640 4 persons, 285.0ms
# Speed: 4.0ms preprocess, 285.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 83
#
# 0: 384x640 4 persons, 204.0ms
# Speed: 3.0ms preprocess, 204.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 84
#
# 0: 384x640 4 persons, 203.0ms
# Speed: 3.0ms preprocess, 203.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 85
#
# 0: 384x640 4 persons, 201.0ms
# Speed: 3.0ms preprocess, 201.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 86
#
# 0: 384x640 4 persons, 214.0ms
# Speed: 3.0ms preprocess, 214.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 87
#
# 0: 384x640 3 persons, 177.0ms
# Speed: 3.0ms preprocess, 177.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 88
#
# 0: 384x640 3 persons, 176.0ms
# Speed: 3.0ms preprocess, 176.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 89
#
# 0: 384x640 3 persons, 175.0ms
# Speed: 3.0ms preprocess, 175.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 90
#
# 0: 384x640 4 persons, 172.0ms
# Speed: 3.1ms preprocess, 172.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 91
#
# 0: 384x640 3 persons, 171.0ms
# Speed: 3.0ms preprocess, 171.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 92
#
# 0: 384x640 3 persons, 177.0ms
# Speed: 3.0ms preprocess, 177.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 93
#
# 0: 384x640 4 persons, 177.0ms
# Speed: 3.0ms preprocess, 177.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 94
#
# 0: 384x640 4 persons, 184.0ms
# Speed: 3.0ms preprocess, 184.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 95
#
# 0: 384x640 3 persons, 188.0ms
# Speed: 3.0ms preprocess, 188.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 96
#
# 0: 384x640 3 persons, 201.0ms
# Speed: 3.0ms preprocess, 201.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 97
#
# 0: 384x640 3 persons, 184.0ms
# Speed: 2.0ms preprocess, 184.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 98
#
# 0: 384x640 3 persons, 183.0ms
# Speed: 3.0ms preprocess, 183.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 99
#
# 0: 384x640 4 persons, 175.0ms
# Speed: 3.0ms preprocess, 175.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 100
#
# 0: 384x640 3 persons, 1 tennis racket, 198.0ms
# Speed: 4.0ms preprocess, 198.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 101
#
# 0: 384x640 3 persons, 179.0ms
# Speed: 3.0ms preprocess, 179.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 102
#
# 0: 384x640 3 persons, 200.0ms
# Speed: 3.0ms preprocess, 200.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 103
#
# 0: 384x640 3 persons, 193.0ms
# Speed: 4.0ms preprocess, 193.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 104
#
# 0: 384x640 3 persons, 191.0ms
# Speed: 3.0ms preprocess, 191.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 105
#
# 0: 384x640 3 persons, 180.0ms
# Speed: 3.0ms preprocess, 180.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 106
#
# 0: 384x640 3 persons, 183.0ms
# Speed: 3.0ms preprocess, 183.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 107
#
# 0: 384x640 3 persons, 199.0ms
# Speed: 3.0ms preprocess, 199.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 108
#
# 0: 384x640 3 persons, 181.0ms
# Speed: 4.0ms preprocess, 181.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 109
#
# 0: 384x640 3 persons, 477.0ms
# Speed: 3.0ms preprocess, 477.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
# 110
#
# 0: 384x640 3 persons, 423.0ms
# Speed: 6.0ms preprocess, 423.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# 111
#
# 0: 384x640 3 persons, 205.0ms
# Speed: 3.0ms preprocess, 205.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 112
#
# 0: 384x640 3 persons, 229.0ms
# Speed: 5.0ms preprocess, 229.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 113
#
# 0: 384x640 4 persons, 212.0ms
# Speed: 4.0ms preprocess, 212.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 114
#
# 0: 384x640 3 persons, 219.0ms
# Speed: 3.0ms preprocess, 219.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 115
#
# 0: 384x640 3 persons, 414.0ms
# Speed: 4.0ms preprocess, 414.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
# 116
#
# 0: 384x640 3 persons, 178.0ms
# Speed: 3.0ms preprocess, 178.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 117
#
# 0: 384x640 3 persons, 182.0ms
# Speed: 3.0ms preprocess, 182.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 118
#
# 0: 384x640 3 persons, 177.0ms
# Speed: 3.0ms preprocess, 177.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 119
#
# 0: 384x640 3 persons, 209.0ms
# Speed: 5.0ms preprocess, 209.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 120
#
# 0: 384x640 3 persons, 172.0ms
# Speed: 4.0ms preprocess, 172.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 121
#
# 0: 384x640 3 persons, 255.0ms
# Speed: 3.0ms preprocess, 255.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 122
#
# 0: 384x640 3 persons, 175.0ms
# Speed: 3.0ms preprocess, 175.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 123
#
# 0: 384x640 4 persons, 189.0ms
# Speed: 3.0ms preprocess, 189.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
# 124
#
# 0: 384x640 3 persons, 195.0ms
# Speed: 3.0ms preprocess, 195.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 125
#
# 0: 384x640 3 persons, 294.0ms
# Speed: 4.0ms preprocess, 294.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
# 126
#
# 0: 384x640 3 persons, 209.0ms
# Speed: 3.0ms preprocess, 209.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 127
#
# 0: 384x640 3 persons, 1 sports ball, 178.0ms
# Speed: 3.0ms preprocess, 178.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 128
#
# 0: 384x640 3 persons, 195.0ms
# Speed: 2.0ms preprocess, 195.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 129
#
# 0: 384x640 3 persons, 205.0ms
# Speed: 2.0ms preprocess, 205.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 130
#
# 0: 384x640 3 persons, 212.0ms
# Speed: 3.0ms preprocess, 212.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 131
#
# 0: 384x640 4 persons, 182.0ms
# Speed: 3.0ms preprocess, 182.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# 132
#
# 0: 384x640 3 persons, 194.0ms
# Speed: 3.0ms preprocess, 194.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 133
#
# 0: 384x640 3 persons, 186.0ms
# Speed: 3.0ms preprocess, 186.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 134
#
# 0: 384x640 3 persons, 191.0ms
# Speed: 3.0ms preprocess, 191.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 135
#
# 0: 384x640 3 persons, 191.0ms
# Speed: 3.0ms preprocess, 191.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 136
#
# 0: 384x640 3 persons, 200.0ms
# Speed: 5.0ms preprocess, 200.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# 137
#
# 0: 384x640 5 persons, 225.0ms
# Speed: 3.0ms preprocess, 225.0ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
# 138
#
# 0: 384x640 4 persons, 193.0ms
# Speed: 3.0ms preprocess, 193.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 139
#
# 0: 384x640 5 persons, 176.0ms
# Speed: 4.0ms preprocess, 176.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 140
#
# 0: 384x640 5 persons, 401.0ms
# Speed: 3.1ms preprocess, 401.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# 141
#
# 0: 384x640 5 persons, 431.0ms
# Speed: 4.0ms preprocess, 431.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# 142
#
# 0: 384x640 5 persons, 215.0ms
# Speed: 4.0ms preprocess, 215.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 143
#
# 0: 384x640 3 persons, 363.0ms
# Speed: 3.0ms preprocess, 363.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# 144
#
# 0: 384x640 3 persons, 542.0ms
# Speed: 5.0ms preprocess, 542.0ms inference, 18.0ms postprocess per image at shape (1, 3, 384, 640)
# 145
#
# 0: 384x640 3 persons, 454.0ms
# Speed: 6.0ms preprocess, 454.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
# 146
#
# 0: 384x640 3 persons, 348.0ms
# Speed: 4.0ms preprocess, 348.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 147
#
# 0: 384x640 3 persons, 210.0ms
# Speed: 4.0ms preprocess, 210.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 148
#
# 0: 384x640 3 persons, 222.0ms
# Speed: 3.0ms preprocess, 222.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 149
#
# 0: 384x640 3 persons, 237.0ms
# Speed: 2.0ms preprocess, 237.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# 150
#
# 0: 384x640 3 persons, 236.0ms
# Speed: 5.0ms preprocess, 236.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 151
#
# 0: 384x640 3 persons, 185.0ms
# Speed: 4.0ms preprocess, 185.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 152
#
# 0: 384x640 3 persons, 202.0ms
# Speed: 4.0ms preprocess, 202.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 153
#
# 0: 384x640 3 persons, 222.0ms
# Speed: 4.0ms preprocess, 222.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 154
#
# 0: 384x640 3 persons, 237.0ms
# Speed: 5.0ms preprocess, 237.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 155
#
# 0: 384x640 3 persons, 177.0ms
# Speed: 3.0ms preprocess, 177.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 156
#
# 0: 384x640 3 persons, 175.0ms
# Speed: 3.0ms preprocess, 175.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 157
#
# 0: 384x640 3 persons, 182.0ms
# Speed: 3.0ms preprocess, 182.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 158
#
# 0: 384x640 3 persons, 204.0ms
# Speed: 3.0ms preprocess, 204.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 159
#
# 0: 384x640 3 persons, 176.0ms
# Speed: 4.0ms preprocess, 176.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 160
#
# 0: 384x640 3 persons, 218.9ms
# Speed: 4.1ms preprocess, 218.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 161
#
# 0: 384x640 2 persons, 234.0ms
# Speed: 3.0ms preprocess, 234.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 162
#
# 0: 384x640 2 persons, 209.0ms
# Speed: 4.0ms preprocess, 209.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 163
#
# 0: 384x640 3 persons, 176.0ms
# Speed: 3.0ms preprocess, 176.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 164
#
# 0: 384x640 3 persons, 196.0ms
# Speed: 3.0ms preprocess, 196.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 165
#
# 0: 384x640 3 persons, 175.0ms
# Speed: 3.0ms preprocess, 175.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 166
#
# 0: 384x640 3 persons, 230.0ms
# Speed: 2.9ms preprocess, 230.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 167
#
# 0: 384x640 3 persons, 216.0ms
# Speed: 4.0ms preprocess, 216.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 168
#
# 0: 384x640 3 persons, 227.0ms
# Speed: 3.0ms preprocess, 227.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 169
#
# 0: 384x640 3 persons, 206.0ms
# Speed: 3.0ms preprocess, 206.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 170
#
# 0: 384x640 3 persons, 576.0ms
# Speed: 5.0ms preprocess, 576.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# 171
#
# 0: 384x640 3 persons, 442.0ms
# Speed: 5.0ms preprocess, 442.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 172
#
# 0: 384x640 3 persons, 187.0ms
# Speed: 3.0ms preprocess, 187.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# 173
#
# 0: 384x640 3 persons, 227.0ms
# Speed: 4.0ms preprocess, 227.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# 174
#
# 0: 384x640 3 persons, 178.0ms
# Speed: 4.0ms preprocess, 178.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 175
#
# 0: 384x640 3 persons, 180.0ms
# Speed: 3.0ms preprocess, 180.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 176
#
# 0: 384x640 3 persons, 184.0ms
# Speed: 3.0ms preprocess, 184.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 177
#
# 0: 384x640 3 persons, 182.0ms
# Speed: 3.0ms preprocess, 182.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 178
#
# 0: 384x640 3 persons, 210.0ms
# Speed: 3.0ms preprocess, 210.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 179
#
# 0: 384x640 4 persons, 230.0ms
# Speed: 3.0ms preprocess, 230.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 180
#
# 0: 384x640 4 persons, 238.0ms
# Speed: 4.0ms preprocess, 238.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 181
#
# 0: 384x640 5 persons, 182.0ms
# Speed: 3.0ms preprocess, 182.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 182
#
# 0: 384x640 5 persons, 180.0ms
# Speed: 3.0ms preprocess, 180.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 183
#
# 0: 384x640 2 persons, 177.0ms
# Speed: 3.0ms preprocess, 177.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 184
#
# 0: 384x640 2 persons, 177.0ms
# Speed: 3.0ms preprocess, 177.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 185
#
# 0: 384x640 2 persons, 184.0ms
# Speed: 4.0ms preprocess, 184.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 186
#
# 0: 384x640 2 persons, 177.0ms
# Speed: 3.0ms preprocess, 177.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 187
#
# 0: 384x640 2 persons, 183.0ms
# Speed: 3.0ms preprocess, 183.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 188
#
# 0: 384x640 2 persons, 186.0ms
# Speed: 3.0ms preprocess, 186.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 189
#
# 0: 384x640 2 persons, 185.0ms
# Speed: 3.0ms preprocess, 185.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 190
#
# 0: 384x640 3 persons, 173.0ms
# Speed: 4.0ms preprocess, 173.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 191
#
# 0: 384x640 4 persons, 195.0ms
# Speed: 2.0ms preprocess, 195.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 192
#
# 0: 384x640 3 persons, 241.0ms
# Speed: 4.0ms preprocess, 241.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 193
#
# 0: 384x640 3 persons, 182.0ms
# Speed: 3.0ms preprocess, 182.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 194
#
# 0: 384x640 3 persons, 182.0ms
# Speed: 2.0ms preprocess, 182.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 195
#
# 0: 384x640 3 persons, 179.0ms
# Speed: 3.0ms preprocess, 179.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 196
#
# 0: 384x640 3 persons, 180.0ms
# Speed: 3.0ms preprocess, 180.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 197
#
# 0: 384x640 3 persons, 176.0ms
# Speed: 3.0ms preprocess, 176.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 198
#
# 0: 384x640 3 persons, 183.0ms
# Speed: 3.0ms preprocess, 183.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 199
#
# 0: 384x640 3 persons, 197.0ms
# Speed: 3.0ms preprocess, 197.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 200
#
# 0: 384x640 3 persons, 1 sports ball, 174.0ms
# Speed: 2.0ms preprocess, 174.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 201
#
# 0: 384x640 3 persons, 1 sports ball, 185.0ms
# Speed: 3.0ms preprocess, 185.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 202
#
# 0: 384x640 3 persons, 179.0ms
# Speed: 3.0ms preprocess, 179.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 203
#
# 0: 384x640 3 persons, 193.0ms
# Speed: 4.0ms preprocess, 193.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 204
#
# 0: 384x640 4 persons, 191.0ms
# Speed: 3.0ms preprocess, 191.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# 205
#
# 0: 384x640 3 persons, 217.0ms
# Speed: 4.0ms preprocess, 217.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# 206
#
# 0: 384x640 3 persons, 262.0ms
# Speed: 6.0ms preprocess, 262.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 207
#
# 0: 384x640 3 persons, 188.0ms
# Speed: 3.0ms preprocess, 188.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 208
#
# 0: 384x640 3 persons, 186.0ms
# Speed: 4.0ms preprocess, 186.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 209
#
# 0: 384x640 3 persons, 206.0ms
# Speed: 3.0ms preprocess, 206.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 210
#
# 0: 384x640 3 persons, 198.0ms
# Speed: 3.0ms preprocess, 198.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 211
#
# 0: 384x640 3 persons, 178.0ms
# Speed: 3.0ms preprocess, 178.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 212
#
# 0: 384x640 3 persons, 194.0ms
# Speed: 3.0ms preprocess, 194.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
# 213
#
# 0: 384x640 3 persons, 281.0ms
# Speed: 3.0ms preprocess, 281.0ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
# 214
#
# 0: 384x640 3 persons, 190.0ms
# Speed: 3.0ms preprocess, 190.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 215
#
# 0: 384x640 3 persons, 204.0ms
# Speed: 5.0ms preprocess, 204.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 216
#
# 0: 384x640 3 persons, 193.0ms
# Speed: 4.0ms preprocess, 193.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 217
#
# 0: 384x640 3 persons, 186.0ms
# Speed: 3.0ms preprocess, 186.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 218
#
# 0: 384x640 3 persons, 180.0ms
# Speed: 3.0ms preprocess, 180.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 219
#
# 0: 384x640 3 persons, 172.0ms
# Speed: 3.0ms preprocess, 172.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 220
#
# 0: 384x640 3 persons, 190.0ms
# Speed: 2.0ms preprocess, 190.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 221
#
# 0: 384x640 3 persons, 175.0ms
# Speed: 2.9ms preprocess, 175.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 222
#
# 0: 384x640 4 persons, 204.0ms
# Speed: 4.0ms preprocess, 204.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 223
#
# 0: 384x640 3 persons, 195.0ms
# Speed: 5.0ms preprocess, 195.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 224
#
# 0: 384x640 3 persons, 221.0ms
# Speed: 4.0ms preprocess, 221.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 225
#
# 0: 384x640 3 persons, 187.0ms
# Speed: 3.0ms preprocess, 187.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 226
#
# 0: 384x640 3 persons, 213.0ms
# Speed: 2.0ms preprocess, 213.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 227
#
# 0: 384x640 3 persons, 193.0ms
# Speed: 3.0ms preprocess, 193.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 228
#
# 0: 384x640 3 persons, 186.0ms
# Speed: 3.0ms preprocess, 186.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 229
#
# 0: 384x640 3 persons, 180.0ms
# Speed: 3.0ms preprocess, 180.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 230
#
# 0: 384x640 4 persons, 178.0ms
# Speed: 3.0ms preprocess, 178.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 231
#
# 0: 384x640 3 persons, 174.0ms
# Speed: 2.0ms preprocess, 174.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 232
#
# 0: 384x640 3 persons, 347.0ms
# Speed: 4.0ms preprocess, 347.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 233
#
# 0: 384x640 3 persons, 197.9ms
# Speed: 3.0ms preprocess, 197.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 234
#
# 0: 384x640 3 persons, 198.0ms
# Speed: 3.0ms preprocess, 198.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 235
#
# 0: 384x640 3 persons, 174.0ms
# Speed: 4.0ms preprocess, 174.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 236
#
# 0: 384x640 3 persons, 173.9ms
# Speed: 3.1ms preprocess, 173.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 237
#
# 0: 384x640 3 persons, 175.0ms
# Speed: 2.0ms preprocess, 175.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 238
#
# 0: 384x640 3 persons, 175.0ms
# Speed: 2.0ms preprocess, 175.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 239
#
# 0: 384x640 3 persons, 176.0ms
# Speed: 2.0ms preprocess, 176.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 240
#
# 0: 384x640 3 persons, 187.0ms
# Speed: 4.0ms preprocess, 187.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 241
#
# 0: 384x640 3 persons, 186.0ms
# Speed: 3.0ms preprocess, 186.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# 242
#
# 0: 384x640 3 persons, 179.0ms
# Speed: 3.0ms preprocess, 179.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 243
#
# 0: 384x640 3 persons, 230.0ms
# Speed: 4.0ms preprocess, 230.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 244
#
# 0: 384x640 3 persons, 187.0ms
# Speed: 2.0ms preprocess, 187.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 245
#
# 0: 384x640 3 persons, 181.0ms
# Speed: 3.0ms preprocess, 181.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 246
#
# 0: 384x640 3 persons, 212.0ms
# Speed: 3.0ms preprocess, 212.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 247
#
# 0: 384x640 3 persons, 179.0ms
# Speed: 3.0ms preprocess, 179.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 248
#
# 0: 384x640 4 persons, 224.0ms
# Speed: 3.0ms preprocess, 224.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 249
#
# 0: 384x640 4 persons, 183.9ms
# Speed: 3.0ms preprocess, 183.9ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 250
#
# 0: 384x640 4 persons, 174.0ms
# Speed: 3.0ms preprocess, 174.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 251
#
# 0: 384x640 3 persons, 178.0ms
# Speed: 3.0ms preprocess, 178.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 252
#
# 0: 384x640 4 persons, 181.0ms
# Speed: 3.0ms preprocess, 181.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 253
#
# 0: 384x640 3 persons, 183.0ms
# Speed: 4.0ms preprocess, 183.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 254
#
# 0: 384x640 4 persons, 184.0ms
# Speed: 3.0ms preprocess, 184.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 255
#
# 0: 384x640 3 persons, 180.0ms
# Speed: 3.0ms preprocess, 180.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 256
#
# 0: 384x640 2 persons, 708.0ms
# Speed: 4.0ms preprocess, 708.0ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
# 257
#
# 0: 384x640 1 person, 362.0ms
# Speed: 4.0ms preprocess, 362.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 258
#
# 0: 384x640 2 persons, 233.0ms
# Speed: 3.0ms preprocess, 233.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 259
#
# 0: 384x640 2 persons, 320.0ms
# Speed: 3.0ms preprocess, 320.0ms inference, 17.0ms postprocess per image at shape (1, 3, 384, 640)
# 260
#
# 0: 384x640 4 persons, 192.0ms
# Speed: 3.0ms preprocess, 192.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 261
#
# 0: 384x640 4 persons, 188.0ms
# Speed: 3.0ms preprocess, 188.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 262
#
# 0: 384x640 4 persons, 178.0ms
# Speed: 4.0ms preprocess, 178.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 263
#
# 0: 384x640 4 persons, 182.0ms
# Speed: 2.0ms preprocess, 182.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 264
#
# 0: 384x640 3 persons, 175.0ms
# Speed: 3.0ms preprocess, 175.0ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# 265
#
# 0: 384x640 4 persons, 176.0ms
# Speed: 2.9ms preprocess, 176.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 266
#
# 0: 384x640 3 persons, 176.0ms
# Speed: 3.0ms preprocess, 176.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 267
#
# 0: 384x640 4 persons, 189.0ms
# Speed: 3.0ms preprocess, 189.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 268
#
# 0: 384x640 4 persons, 176.0ms
# Speed: 3.0ms preprocess, 176.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 269
#
# 0: 384x640 4 persons, 175.0ms
# Speed: 3.0ms preprocess, 175.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 270
#
# 0: 384x640 4 persons, 180.0ms
# Speed: 3.0ms preprocess, 180.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 271
#
# 0: 384x640 3 persons, 196.0ms
# Speed: 3.0ms preprocess, 196.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 272
#
# 0: 384x640 4 persons, 176.0ms
# Speed: 3.0ms preprocess, 176.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 273
#
# 0: 384x640 3 persons, 177.0ms
# Speed: 3.0ms preprocess, 177.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 274
#
# 0: 384x640 3 persons, 177.0ms
# Speed: 3.0ms preprocess, 177.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 275
#
# 0: 384x640 3 persons, 179.0ms
# Speed: 3.0ms preprocess, 179.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 276
#
# 0: 384x640 3 persons, 175.0ms
# Speed: 4.0ms preprocess, 175.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 277
#
# 0: 384x640 3 persons, 174.0ms
# Speed: 3.0ms preprocess, 174.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 278
#
# 0: 384x640 3 persons, 177.0ms
# Speed: 3.0ms preprocess, 177.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 279
#
# 0: 384x640 3 persons, 184.0ms
# Speed: 3.0ms preprocess, 184.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 280
#
# 0: 384x640 3 persons, 178.0ms
# Speed: 3.0ms preprocess, 178.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 281
#
# 0: 384x640 3 persons, 176.0ms
# Speed: 4.0ms preprocess, 176.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 282
#
# 0: 384x640 4 persons, 175.0ms
# Speed: 3.0ms preprocess, 175.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 283
#
# 0: 384x640 4 persons, 174.0ms
# Speed: 4.0ms preprocess, 174.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 284
#
# 0: 384x640 3 persons, 173.0ms
# Speed: 3.0ms preprocess, 173.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 285
#
# 0: 384x640 3 persons, 175.0ms
# Speed: 3.0ms preprocess, 175.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 286
#
# 0: 384x640 3 persons, 174.9ms
# Speed: 3.1ms preprocess, 174.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 287
#
# 0: 384x640 3 persons, 178.0ms
# Speed: 3.0ms preprocess, 178.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 288
#
# 0: 384x640 3 persons, 182.0ms
# Speed: 3.0ms preprocess, 182.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 289
#
# 0: 384x640 3 persons, 172.0ms
# Speed: 3.0ms preprocess, 172.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 290
#
# 0: 384x640 3 persons, 186.0ms
# Speed: 4.0ms preprocess, 186.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 291
#
# 0: 384x640 3 persons, 172.0ms
# Speed: 3.0ms preprocess, 172.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 292
#
# 0: 384x640 3 persons, 1 sports ball, 178.9ms
# Speed: 3.1ms preprocess, 178.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 293
#
# 0: 384x640 3 persons, 175.0ms
# Speed: 2.0ms preprocess, 175.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 294
#
# 0: 384x640 3 persons, 174.0ms
# Speed: 2.0ms preprocess, 174.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 295
#
# 0: 384x640 3 persons, 176.0ms
# Speed: 3.0ms preprocess, 176.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 296
#
# 0: 384x640 3 persons, 176.0ms
# Speed: 4.0ms preprocess, 176.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 297
#
# 0: 384x640 3 persons, 1 sports ball, 174.0ms
# Speed: 3.0ms preprocess, 174.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 298
#
# 0: 384x640 3 persons, 1 sports ball, 179.0ms
# Speed: 4.0ms preprocess, 179.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 299
#
# 0: 384x640 3 persons, 1 sports ball, 176.0ms
# Speed: 3.1ms preprocess, 176.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 300
#
# 0: 384x640 3 persons, 1 sports ball, 199.0ms
# Speed: 3.0ms preprocess, 199.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 301
#
# 0: 384x640 3 persons, 174.0ms
# Speed: 3.0ms preprocess, 174.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 302
#
# 0: 384x640 3 persons, 180.0ms
# Speed: 4.0ms preprocess, 180.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 303
#
# 0: 384x640 3 persons, 180.0ms
# Speed: 3.0ms preprocess, 180.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 304
#
# 0: 384x640 3 persons, 173.0ms
# Speed: 3.0ms preprocess, 173.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 305
#
# 0: 384x640 3 persons, 177.0ms
# Speed: 3.0ms preprocess, 177.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 306
#
# 0: 384x640 3 persons, 175.0ms
# Speed: 2.0ms preprocess, 175.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 307
#
# 0: 384x640 3 persons, 176.0ms
# Speed: 4.0ms preprocess, 176.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 308
#
# 0: 384x640 3 persons, 174.0ms
# Speed: 2.0ms preprocess, 174.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 309
#
# 0: 384x640 3 persons, 174.0ms
# Speed: 3.0ms preprocess, 174.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 310
#
# 0: 384x640 3 persons, 174.0ms
# Speed: 4.0ms preprocess, 174.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 311
#
# 0: 384x640 4 persons, 177.0ms
# Speed: 3.0ms preprocess, 177.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 312
#
# 0: 384x640 3 persons, 177.0ms
# Speed: 3.0ms preprocess, 177.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 313
#
# 0: 384x640 3 persons, 181.0ms
# Speed: 3.0ms preprocess, 181.0ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
# 314
#
# 0: 384x640 4 persons, 174.0ms
# Speed: 3.0ms preprocess, 174.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 315
#
# 0: 384x640 3 persons, 181.0ms
# Speed: 3.0ms preprocess, 181.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 316
#
# 0: 384x640 3 persons, 174.0ms
# Speed: 2.0ms preprocess, 174.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 317
#
# 0: 384x640 4 persons, 178.0ms
# Speed: 4.0ms preprocess, 178.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 318
#
# 0: 384x640 3 persons, 205.0ms
# Speed: 4.0ms preprocess, 205.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 319
#
# 0: 384x640 3 persons, 174.0ms
# Speed: 3.0ms preprocess, 174.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 320
#
# 0: 384x640 3 persons, 191.0ms
# Speed: 3.0ms preprocess, 191.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 321
#
# 0: 384x640 3 persons, 175.0ms
# Speed: 3.0ms preprocess, 175.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 322
#
# 0: 384x640 3 persons, 205.0ms
# Speed: 3.0ms preprocess, 205.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 323
#
# 0: 384x640 3 persons, 181.0ms
# Speed: 3.1ms preprocess, 181.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 324
#
# 0: 384x640 3 persons, 180.0ms
# Speed: 3.0ms preprocess, 180.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 325
#
# 0: 384x640 3 persons, 178.0ms
# Speed: 4.0ms preprocess, 178.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 326
#
# 0: 384x640 3 persons, 183.9ms
# Speed: 3.0ms preprocess, 183.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 327
#
# 0: 384x640 3 persons, 174.0ms
# Speed: 3.0ms preprocess, 174.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 328
#
# 0: 384x640 3 persons, 174.0ms
# Speed: 3.0ms preprocess, 174.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 329
#
# 0: 384x640 3 persons, 172.0ms
# Speed: 3.0ms preprocess, 172.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 330
#
# 0: 384x640 3 persons, 172.0ms
# Speed: 2.0ms preprocess, 172.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 331
#
# 0: 384x640 3 persons, 174.0ms
# Speed: 3.0ms preprocess, 174.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 332
#
# 0: 384x640 3 persons, 203.0ms
# Speed: 3.0ms preprocess, 203.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 333
#
# 0: 384x640 3 persons, 175.0ms
# Speed: 3.0ms preprocess, 175.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 334
#
# 0: 384x640 3 persons, 181.0ms
# Speed: 3.1ms preprocess, 181.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 335
#
# 0: 384x640 3 persons, 180.0ms
# Speed: 3.0ms preprocess, 180.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 336
#
# 0: 384x640 3 persons, 185.0ms
# Speed: 2.0ms preprocess, 185.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 337
#
# 0: 384x640 3 persons, 185.0ms
# Speed: 3.0ms preprocess, 185.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 338
#
# 0: 384x640 3 persons, 176.0ms
# Speed: 2.0ms preprocess, 176.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 339
#
# 0: 384x640 3 persons, 175.0ms
# Speed: 3.0ms preprocess, 175.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 340
#
# 0: 384x640 3 persons, 228.0ms
# Speed: 3.0ms preprocess, 228.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 341
#
# 0: 384x640 3 persons, 180.0ms
# Speed: 3.0ms preprocess, 180.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 342
#
# 0: 384x640 3 persons, 176.0ms
# Speed: 3.0ms preprocess, 176.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 343
#
# 0: 384x640 3 persons, 177.0ms
# Speed: 3.0ms preprocess, 177.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 344
#
# 0: 384x640 3 persons, 179.0ms
# Speed: 3.0ms preprocess, 179.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 345
#
# 0: 384x640 3 persons, 1 sports ball, 175.0ms
# Speed: 3.0ms preprocess, 175.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 346
#
# 0: 384x640 3 persons, 174.0ms
# Speed: 3.0ms preprocess, 174.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 347
#
# 0: 384x640 3 persons, 177.0ms
# Speed: 3.0ms preprocess, 177.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 348
#
# 0: 384x640 3 persons, 222.0ms
# Speed: 3.0ms preprocess, 222.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 349
#
# 0: 384x640 3 persons, 221.0ms
# Speed: 2.0ms preprocess, 221.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 350
#
# 0: 384x640 3 persons, 173.0ms
# Speed: 3.0ms preprocess, 173.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 351
#
# 0: 384x640 3 persons, 175.0ms
# Speed: 3.0ms preprocess, 175.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 352
#
# 0: 384x640 3 persons, 179.0ms
# Speed: 3.1ms preprocess, 179.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 353
#
# 0: 384x640 3 persons, 207.0ms
# Speed: 3.0ms preprocess, 207.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 354
#
# 0: 384x640 3 persons, 214.0ms
# Speed: 3.0ms preprocess, 214.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# 355
#
# 0: 384x640 3 persons, 256.0ms
# Speed: 3.0ms preprocess, 256.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 356
#
# ...
# 5921
#
# 0: 384x640 4 persons, 176.0ms
# Speed: 3.0ms preprocess, 176.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 5922
#
# 0: 384x640 4 persons, 250.0ms
# Speed: 2.0ms preprocess, 250.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# 5923
#
# 0: 384x640 4 persons, 317.0ms
# Speed: 5.0ms preprocess, 317.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# 5924
#
# 0: 384x640 4 persons, 332.0ms
# Speed: 4.0ms preprocess, 332.0ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
# 5925
#
# 0: 384x640 4 persons, 254.0ms
# Speed: 5.0ms preprocess, 254.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
# 5926
#
# 0: 384x640 4 persons, 244.0ms
# Speed: 4.0ms preprocess, 244.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 5927
#
# 0: 384x640 4 persons, 321.0ms
# Speed: 4.0ms preprocess, 321.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
# 5928
#
# 0: 384x640 4 persons, 244.0ms
# Speed: 4.0ms preprocess, 244.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 5929
#
# 0: 384x640 4 persons, 217.0ms
# Speed: 3.0ms preprocess, 217.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 5930
#
# 0: 384x640 4 persons, 232.0ms
# Speed: 4.0ms preprocess, 232.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 5931
#
# 0: 384x640 4 persons, 296.0ms
# Speed: 6.0ms preprocess, 296.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# 5932
#
# 0: 384x640 4 persons, 289.0ms
# Speed: 5.0ms preprocess, 289.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
# 5933
#
# 0: 384x640 4 persons, 211.0ms
# Speed: 3.0ms preprocess, 211.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 5934
#
# 0: 384x640 4 persons, 238.0ms
# Speed: 4.0ms preprocess, 238.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 5935
#
# 0: 384x640 4 persons, 230.0ms
# Speed: 3.0ms preprocess, 230.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 5936
#
# 0: 384x640 4 persons, 238.0ms
# Speed: 3.0ms preprocess, 238.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 5937
#
# 0: 384x640 5 persons, 204.0ms
# Speed: 3.0ms preprocess, 204.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 5938
#
# 0: 384x640 5 persons, 236.0ms
# Speed: 3.0ms preprocess, 236.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 5939
#
# 0: 384x640 5 persons, 302.0ms
# Speed: 4.0ms preprocess, 302.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 5940
#
# 0: 384x640 5 persons, 293.0ms
# Speed: 3.0ms preprocess, 293.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 5941
#
# 0: 384x640 5 persons, 317.0ms
# Speed: 4.0ms preprocess, 317.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 5942
#
# 0: 384x640 5 persons, 297.0ms
# Speed: 4.0ms preprocess, 297.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 5943
#
# 0: 384x640 5 persons, 241.0ms
# Speed: 4.0ms preprocess, 241.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 5944
#
# 0: 384x640 4 persons, 274.0ms
# Speed: 3.0ms preprocess, 274.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 5945
#
# 0: 384x640 4 persons, 313.0ms
# Speed: 3.0ms preprocess, 313.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 5946
#
# 0: 384x640 4 persons, 247.0ms
# Speed: 4.0ms preprocess, 247.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 5947
#
# 0: 384x640 4 persons, 314.0ms
# Speed: 4.0ms preprocess, 314.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 5948
#
# 0: 384x640 4 persons, 235.0ms
# Speed: 3.0ms preprocess, 235.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 5949
#
# 0: 384x640 4 persons, 264.0ms
# Speed: 3.0ms preprocess, 264.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 5950
#
# 0: 384x640 4 persons, 244.0ms
# Speed: 4.0ms preprocess, 244.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 5951
#
# 0: 384x640 3 persons, 253.0ms
# Speed: 4.0ms preprocess, 253.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 5952
#
# 0: 384x640 3 persons, 252.0ms
# Speed: 3.0ms preprocess, 252.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 5953
#
# 0: 384x640 3 persons, 264.0ms
# Speed: 4.0ms preprocess, 264.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 5954
#
# 0: 384x640 3 persons, 232.0ms
# Speed: 3.0ms preprocess, 232.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 5955
#
# 0: 384x640 3 persons, 221.0ms
# Speed: 3.0ms preprocess, 221.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# 5956
#
# 0: 384x640 3 persons, 207.0ms
# Speed: 3.0ms preprocess, 207.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 5957
#
# 0: 384x640 3 persons, 206.0ms
# Speed: 3.0ms preprocess, 206.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 5958
#
# 0: 384x640 3 persons, 212.0ms
# Speed: 4.0ms preprocess, 212.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 5959
#
# 0: 384x640 3 persons, 206.0ms
# Speed: 3.0ms preprocess, 206.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 5960
#
# 0: 384x640 3 persons, 210.0ms
# Speed: 4.0ms preprocess, 210.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 5961
#
# 0: 384x640 3 persons, 221.0ms
# Speed: 3.0ms preprocess, 221.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 5962
#
# 0: 384x640 3 persons, 307.0ms
# Speed: 3.0ms preprocess, 307.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 5963
#
# 0: 384x640 3 persons, 304.0ms
# Speed: 3.0ms preprocess, 304.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 5964
#
# 0: 384x640 3 persons, 199.0ms
# Speed: 4.0ms preprocess, 199.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 5965
#
# 0: 384x640 3 persons, 261.0ms
# Speed: 3.0ms preprocess, 261.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 5966
#
# 0: 384x640 3 persons, 221.0ms
# Speed: 4.0ms preprocess, 221.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 5967
#
# 0: 384x640 3 persons, 252.0ms
# Speed: 4.0ms preprocess, 252.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 5968
#
# 0: 384x640 3 persons, 441.0ms
# Speed: 5.0ms preprocess, 441.0ms inference, 16.0ms postprocess per image at shape (1, 3, 384, 640)
# 5969
#
# 0: 384x640 3 persons, 330.0ms
# Speed: 4.0ms preprocess, 330.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 5970
#
# 0: 384x640 3 persons, 292.0ms
# Speed: 4.0ms preprocess, 292.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 5971
#
# 0: 384x640 3 persons, 279.0ms
# Speed: 3.0ms preprocess, 279.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# 5972
#
# 0: 384x640 3 persons, 249.0ms
# Speed: 4.0ms preprocess, 249.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 5973
#
# 0: 384x640 3 persons, 189.0ms
# Speed: 3.0ms preprocess, 189.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 5974
#
# 0: 384x640 3 persons, 211.0ms
# Speed: 3.0ms preprocess, 211.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 5975
#
# 0: 384x640 3 persons, 282.0ms
# Speed: 2.0ms preprocess, 282.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
# 5976
#
# 0: 384x640 3 persons, 288.0ms
# Speed: 4.0ms preprocess, 288.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 5977
#
# 0: 384x640 3 persons, 1018.0ms
# Speed: 6.0ms preprocess, 1018.0ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
# 5978
#
# 0: 384x640 3 persons, 481.0ms
# Speed: 5.0ms preprocess, 481.0ms inference, 10.0ms postprocess per image at shape (1, 3, 384, 640)
# 5979
#
# 0: 384x640 3 persons, 482.0ms
# Speed: 5.0ms preprocess, 482.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# 5980
#
# 0: 384x640 3 persons, 370.0ms
# Speed: 3.0ms preprocess, 370.0ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# 5981
#
# 0: 384x640 3 persons, 535.0ms
# Speed: 3.0ms preprocess, 535.0ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
# 5982
#
# 0: 384x640 3 persons, 317.0ms
# Speed: 5.0ms preprocess, 317.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 5983
#
# 0: 384x640 3 persons, 463.0ms
# Speed: 4.0ms preprocess, 463.0ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
# 5984
#
# 0: 384x640 3 persons, 523.0ms
# Speed: 5.0ms preprocess, 523.0ms inference, 10.0ms postprocess per image at shape (1, 3, 384, 640)
# 5985
#
# 0: 384x640 4 persons, 230.0ms
# Speed: 3.0ms preprocess, 230.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 5986
#
# 0: 384x640 3 persons, 218.0ms
# Speed: 3.0ms preprocess, 218.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 5987
#
# 0: 384x640 3 persons, 182.0ms
# Speed: 2.0ms preprocess, 182.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 5988
#
# 0: 384x640 3 persons, 176.0ms
# Speed: 3.0ms preprocess, 176.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 5989
#
# 0: 384x640 3 persons, 201.0ms
# Speed: 3.0ms preprocess, 201.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# 5990
#
# 0: 384x640 3 persons, 289.0ms
# Speed: 4.0ms preprocess, 289.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
# 5991
#
# 0: 384x640 3 persons, 353.0ms
# Speed: 4.0ms preprocess, 353.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
# 5992
#
# 0: 384x640 3 persons, 262.0ms
# Speed: 3.0ms preprocess, 262.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 5993
#
# 0: 384x640 3 persons, 317.0ms
# Speed: 3.0ms preprocess, 317.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 5994
#
# 0: 384x640 3 persons, 330.0ms
# Speed: 4.0ms preprocess, 330.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 5995
#
# 0: 384x640 3 persons, 412.0ms
# Speed: 5.0ms preprocess, 412.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# 5996
#
# 0: 384x640 3 persons, 323.0ms
# Speed: 6.0ms preprocess, 323.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 5997
#
# 0: 384x640 3 persons, 340.0ms
# Speed: 4.0ms preprocess, 340.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
# 5998
#
# 0: 384x640 3 persons, 444.0ms
# Speed: 4.0ms preprocess, 444.0ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
# 5999
#
# 0: 384x640 3 persons, 463.0ms
# Speed: 5.0ms preprocess, 463.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# 6000
#
# 0: 384x640 3 persons, 512.0ms
# Speed: 5.0ms preprocess, 512.0ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# 6001
#
# 0: 384x640 3 persons, 363.0ms
# Speed: 4.0ms preprocess, 363.0ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
# 6002
#
# 0: 384x640 3 persons, 405.0ms
# Speed: 4.0ms preprocess, 405.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
# 6003
#
# 0: 384x640 3 persons, 541.0ms
# Speed: 4.0ms preprocess, 541.0ms inference, 12.0ms postprocess per image at shape (1, 3, 384, 640)
# 6004
#
# 0: 384x640 3 persons, 384.0ms
# Speed: 5.0ms preprocess, 384.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
# 6005
#
# 0: 384x640 3 persons, 467.0ms
# Speed: 5.0ms preprocess, 467.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
# 6006
#
# 0: 384x640 3 persons, 410.0ms
# Speed: 4.0ms preprocess, 410.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# 6007
#
# 0: 384x640 3 persons, 432.0ms
# Speed: 6.0ms preprocess, 432.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
# 6008
#
# 0: 384x640 3 persons, 378.0ms
# Speed: 4.0ms preprocess, 378.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 6009
#
# 0: 384x640 3 persons, 473.0ms
# Speed: 3.0ms preprocess, 473.0ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
# 6010
#
# 0: 384x640 3 persons, 431.0ms
# Speed: 5.0ms preprocess, 431.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# 6011
#
# 0: 384x640 3 persons, 340.0ms
# Speed: 3.0ms preprocess, 340.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 6012
#
# 0: 384x640 3 persons, 313.0ms
# Speed: 3.0ms preprocess, 313.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 6013
#
# 0: 384x640 3 persons, 229.0ms
# Speed: 3.0ms preprocess, 229.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# 6014
#
# 0: 384x640 3 persons, 265.0ms
# Speed: 3.0ms preprocess, 265.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 6015
#
# 0: 384x640 4 persons, 240.0ms
# Speed: 3.0ms preprocess, 240.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 6016
#
# 0: 384x640 5 persons, 261.0ms
# Speed: 2.0ms preprocess, 261.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 6017
#
# 0: 384x640 2 persons, 313.0ms
# Speed: 3.0ms preprocess, 313.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 6018
#
# 0: 384x640 2 persons, 291.0ms
# Speed: 6.0ms preprocess, 291.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 6019
#
# 0: 384x640 2 persons, 323.0ms
# Speed: 4.0ms preprocess, 323.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
# 6020
#
# 0: 384x640 2 persons, 518.0ms
# Speed: 5.0ms preprocess, 518.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
# 6021
#
# 0: 384x640 2 persons, 551.0ms
# Speed: 5.0ms preprocess, 551.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# 6022
#
# 0: 384x640 2 persons, 449.0ms
# Speed: 4.0ms preprocess, 449.0ms inference, 32.0ms postprocess per image at shape (1, 3, 384, 640)
# 6023
#
# 0: 384x640 2 persons, 1 skateboard, 567.0ms
# Speed: 3.0ms preprocess, 567.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 6024
#
# 0: 384x640 2 persons, 521.0ms
# Speed: 4.0ms preprocess, 521.0ms inference, 17.0ms postprocess per image at shape (1, 3, 384, 640)
# 6025
#
# 0: 384x640 2 persons, 521.0ms
# Speed: 5.0ms preprocess, 521.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
# 6026
#
# 0: 384x640 2 persons, 484.0ms
# Speed: 5.0ms preprocess, 484.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# 6027
#
# 0: 384x640 3 persons, 540.0ms
# Speed: 4.0ms preprocess, 540.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
# 6028
#
# 0: 384x640 2 persons, 526.0ms
# Speed: 5.0ms preprocess, 526.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
# 6029
#
# 0: 384x640 2 persons, 459.0ms
# Speed: 4.0ms preprocess, 459.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
# 6030
#
# 0: 384x640 3 persons, 451.0ms
# Speed: 5.0ms preprocess, 451.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# 6031
#
# 0: 384x640 2 persons, 349.0ms
# Speed: 3.0ms preprocess, 349.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 6032
#
# 0: 384x640 3 persons, 263.0ms
# Speed: 3.0ms preprocess, 263.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 6033
#
# 0: 384x640 3 persons, 208.0ms
# Speed: 2.9ms preprocess, 208.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 6034
#
# 0: 384x640 2 persons, 206.0ms
# Speed: 2.0ms preprocess, 206.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 6035
#
# 0: 384x640 4 persons, 204.0ms
# Speed: 3.0ms preprocess, 204.0ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# 6036
#
# 0: 384x640 4 persons, 215.4ms
# Speed: 3.0ms preprocess, 215.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 6037
#
# 0: 384x640 2 persons, 215.0ms
# Speed: 3.0ms preprocess, 215.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 6038
#
# 0: 384x640 2 persons, 320.9ms
# Speed: 3.1ms preprocess, 320.9ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 6039
