# %%
import cv2
import os
from ultralytics import YOLO
import mediapipe as mp
import xml.etree.ElementTree as ET
import string
import random

# %%
# Load YOLOv8 model
model_path = 'yolov8n.pt'  # Using a pre-trained YOLOv8 model
model = YOLO(model_path)

# Initialize MediaPipe Pose
mp_pose = mp.solutions.pose
pose = mp_pose.Pose(static_image_mode=True, model_complexity=2, enable_segmentation=False, min_detection_confidence=0.5)

# %%
# Directory to save results
bbox_output_dir = 'C:/Users/alimo/OneDrive/Documents/FRT/YOLO MediaPipe Pose Detection/YOLOv8-Mediapipe-Pose-Detection/Output/Detected_Bbox'
Handsup_output_dir = 'C:/Users/alimo/OneDrive/Documents/FRT/YOLO MediaPipe Pose Detection/YOLOv8-Mediapipe-Pose-Detection/Output/Hands_Up'
xml_dir = 'C:/Users/alimo/OneDrive/Documents/FRT/YOLO MediaPipe Pose Detection/YOLOv8-Mediapipe-Pose-Detection/Output/XML_Files'

video_dir = 'C:/Users/alimo/OneDrive/Documents/FRT/YOLO MediaPipe Pose Detection/YOLOv8-Mediapipe-Pose-Detection/Videos_data'  # Update with video path

os.makedirs(Handsup_output_dir, exist_ok=True)
os.makedirs(xml_dir, exist_ok=True)
os.makedirs(bbox_output_dir, exist_ok=True)

# Confidence threshold
confidence_threshold = 0.5

# %%
def get_pose_landmarks(image):
    results = pose.process(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    if results.pose_landmarks:
        keypoints = [landmark for landmark in results.pose_landmarks.landmark if landmark.visibility > confidence_threshold]
        if len(keypoints) > len(results.pose_landmarks.landmark) / 2:
            return results.pose_landmarks
    return None

# %%
def classify_pose(landmarks):
    if not landmarks:
        return "No pose detected"

    landmarks_list = [landmark for landmark in landmarks.landmark]

    left_wrist = landmarks_list[mp_pose.PoseLandmark.LEFT_WRIST.value]
    right_wrist = landmarks_list[mp_pose.PoseLandmark.RIGHT_WRIST.value]
    left_eye = landmarks_list[mp_pose.PoseLandmark.LEFT_EYE.value]
    right_eye = landmarks_list[mp_pose.PoseLandmark.RIGHT_EYE.value]
    nose = landmarks_list[mp_pose.PoseLandmark.NOSE.value]

    # Check if either wrist is above the eyes or nose
    if (left_wrist.y < left_eye.y or left_wrist.y < nose.y) and (right_wrist.y < right_eye.y or right_wrist.y < nose.y):
        return "Hands Up"
    else:
        return "Other Pose"

# %%
def create_xml_for_bounding_box(bounding_box, file_name, save_directory):
    """
    Create an XML file for a given bounding box and file name, and save it to the specified directory.

    Parameters:
    bounding_box (tuple): A tuple containing (xmin, ymin, xmax, ymax).
    file_name (str): The name of the file (without extension).
    save_directory (str): The directory where the XML file will be saved.

    Returns:
    str: The name of the created XML file.
    """
    # Ensure the save directory exists
    os.makedirs(save_directory, exist_ok=True)

    # Define the root element
    annotation = ET.Element('annotation')

    # Define the folder element
    folder = ET.SubElement(annotation, 'folder')
    folder.text = 'images'

    # Define the filename element
    filename = ET.SubElement(annotation, 'filename')
    filename.text = f"{file_name}.jpg"

    # Define the path element
    path = ET.SubElement(annotation, 'path')
    path.text = os.path.join('Output\XML_Files', f"{file_name}.jpg")

    # Define the source element
    source = ET.SubElement(annotation, 'source')
    database = ET.SubElement(source, 'database')
    database.text = 'Unknown'

    # Define the size element
    size = ET.SubElement(annotation, 'size')
    width = ET.SubElement(size, 'width')
    width.text = '1280'  # Placeholder value
    height = ET.SubElement(size, 'height')
    height.text = '720'  # Placeholder value
    depth = ET.SubElement(size, 'depth')
    depth.text = '3'  # Assuming RGB images

    # Define the segmented element
    segmented = ET.SubElement(annotation, 'segmented')
    segmented.text = '0'

    # Define the object element
    obj = ET.SubElement(annotation, 'object')
    name = ET.SubElement(obj, 'name')
    name.text = 'shooting player'
    pose = ET.SubElement(obj, 'pose')
    pose.text = 'Unspecified'
    truncated = ET.SubElement(obj, 'truncated')
    truncated.text = '0'
    difficult = ET.SubElement(obj, 'difficult')
    difficult.text = '0'
    bndbox = ET.SubElement(obj, 'bndbox')
    xmin = ET.SubElement(bndbox, 'xmin')
    xmin.text = str(int(bounding_box[0]))
    ymin = ET.SubElement(bndbox, 'ymin')
    ymin.text = str(int(bounding_box[1]))
    xmax = ET.SubElement(bndbox, 'xmax')
    xmax.text = str(int(bounding_box[2]))
    ymax = ET.SubElement(bndbox, 'ymax')
    ymax.text = str(int(bounding_box[3]))

    # Convert the tree to a string and write it to a file
    tree = ET.ElementTree(annotation)
    xml_file_name = os.path.join(save_directory, f"{file_name}.xml")
    tree.write(xml_file_name)

# %%
def detect_person(model, frame):
    results = model.predict(frame)
    detected_persons = []

    for result in results:
        boxes = result.boxes.xyxy.cpu().numpy()
        scores = result.boxes.conf.cpu().numpy()
        class_ids = result.boxes.cls.cpu().numpy()

        for box, score, class_id in zip(boxes, scores, class_ids):
            if class_id == 0 and score > confidence_threshold:  # Class 0 is 'person' in COCO dataset
                x1, y1, x2, y2 = map(int, box)
                height = y2 - y1
                width = x2 - x1
                center_x = (x1 + x2) // 2
                x1 = center_x - height // 2
                x2 = center_x + height // 2
                x1 = max(0, x1)
                x2 = min(frame.shape[1], x2)
                cropped_person = frame[y1:y2, x1:x2]
                landmarks = get_pose_landmarks(cropped_person)
                pose_label = classify_pose(landmarks)
                if pose_label == "Hands Up":
                    print('Hands UP')
                    detected_persons.append((box, score, class_id, pose_label))
    return detected_persons

# %%
def generate_random_name(length=8):
    """ Generate a random string of letters and digits.
    """
    chars = string.ascii_letters + string.digits
    return ''.join(random.choice(chars) for _ in range(length))

# %%
def video_proscessor():
    # Process each video
    frame_counter = 0
    count=0

    for video_file in os.listdir(video_dir):
        if video_file.endswith('.mp4'):
            video_path = os.path.join(video_dir, video_file)
            cap = cv2.VideoCapture(video_path)

            while cap.isOpened():
                ret, frame = cap.read()
                if not ret:
                    break
                count+=1
                detected_persons = detect_person(model, frame)

                for box, score, class_id, pose_label in detected_persons:
                    
                    file_name = f'{generate_random_name()}.jpg'
                    file_path = os.path.join(Handsup_output_dir,file_name)
                    cv2.imwrite(file_path, frame)
                    
                    x1, y1, x2, y2 = map(int, box)
                    cv2.rectangle(frame, (x1, y1), (x2, y2), (255, 0, 0), 2)
                    image_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
                    bbox_file_path = os.path.join(bbox_output_dir, file_name)
                    cv2.imwrite(bbox_file_path, image_rgb)

                    # create_pascal_voc_annotation(file_name, frame.shape, bounding_boxes, xml_dir)
                    create_xml_for_bounding_box(box, file_name.replace('.jpg', ''), xml_dir)
                    frame_counter += 1
                print(count)
            cap.release()

# %%
if __name__== '__main__':
    video_proscessor()
# Out:
# 0: 384x640 2 persons, 3 tvs, 1 microwave, 333.5ms
# Speed: 16.9ms preprocess, 333.5ms inference, 16.6ms postprocess per image at shape (1, 3, 384, 640)
# 1
#
# 0: 384x640 2 persons, 3 tvs, 1 microwave, 228.2ms
# Speed: 0.0ms preprocess, 228.2ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
# 2
#
# 0: 384x640 2 persons, 3 tvs, 1 microwave, 211.7ms
# Speed: 0.0ms preprocess, 211.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 3
#
# 0: 384x640 2 persons, 3 tvs, 1 microwave, 211.1ms
# Speed: 5.2ms preprocess, 211.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 4
#
# 0: 384x640 2 persons, 3 tvs, 1 microwave, 200.0ms
# Speed: 3.5ms preprocess, 200.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# 5
#
# 0: 384x640 2 persons, 3 tvs, 1 microwave, 229.1ms
# Speed: 0.0ms preprocess, 229.1ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
# 6
#
# 0: 384x640 2 persons, 4 tvs, 1 microwave, 303.5ms
# Speed: 3.6ms preprocess, 303.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 7
#
# 0: 384x640 2 persons, 3 tvs, 1 microwave, 399.6ms
# Speed: 10.5ms preprocess, 399.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 8
#
# 0: 384x640 2 persons, 4 tvs, 1 microwave, 278.1ms
# Speed: 6.7ms preprocess, 278.1ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# 9
#
# 0: 384x640 2 persons, 4 tvs, 1 microwave, 217.2ms
# Speed: 0.0ms preprocess, 217.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 10
#
# 0: 384x640 2 persons, 4 tvs, 1 microwave, 197.7ms
# Speed: 4.1ms preprocess, 197.7ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 11
#
# 0: 384x640 2 persons, 3 tvs, 1 microwave, 192.8ms
# Speed: 6.9ms preprocess, 192.8ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
# 12
#
# 0: 384x640 2 persons, 2 tvs, 1 microwave, 724.7ms
# Speed: 0.0ms preprocess, 724.7ms inference, 19.2ms postprocess per image at shape (1, 3, 384, 640)
# 13
#
# 0: 384x640 2 persons, 3 tvs, 1 microwave, 757.1ms
# Speed: 6.1ms preprocess, 757.1ms inference, 20.1ms postprocess per image at shape (1, 3, 384, 640)
# 14
#
# 0: 384x640 2 persons, 3 tvs, 1 microwave, 628.0ms
# Speed: 10.1ms preprocess, 628.0ms inference, 12.9ms postprocess per image at shape (1, 3, 384, 640)
# 15
#
# 0: 384x640 2 persons, 3 tvs, 1 microwave, 663.2ms
# Speed: 8.8ms preprocess, 663.2ms inference, 16.6ms postprocess per image at shape (1, 3, 384, 640)
# 16
#
# 0: 384x640 2 persons, 2 tvs, 1 microwave, 480.1ms
# Speed: 6.5ms preprocess, 480.1ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
# 17
#
# 0: 384x640 2 persons, 3 tvs, 1 microwave, 570.7ms
# Speed: 8.8ms preprocess, 570.7ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
# 18
#
# 0: 384x640 2 persons, 3 tvs, 1 microwave, 560.4ms
# Speed: 8.1ms preprocess, 560.4ms inference, 15.5ms postprocess per image at shape (1, 3, 384, 640)
# 19
#
# 0: 384x640 2 persons, 3 tvs, 1 microwave, 504.2ms
# Speed: 4.7ms preprocess, 504.2ms inference, 8.6ms postprocess per image at shape (1, 3, 384, 640)
# 20
#
# 0: 384x640 2 persons, 4 tvs, 1 microwave, 635.0ms
# Speed: 12.5ms preprocess, 635.0ms inference, 8.4ms postprocess per image at shape (1, 3, 384, 640)
# 21
#
# 0: 384x640 2 persons, 3 tvs, 1 microwave, 653.4ms
# Speed: 5.7ms preprocess, 653.4ms inference, 16.1ms postprocess per image at shape (1, 3, 384, 640)
# 22
#
# 0: 384x640 2 persons, 3 tvs, 1 microwave, 482.3ms
# Speed: 4.5ms preprocess, 482.3ms inference, 10.9ms postprocess per image at shape (1, 3, 384, 640)
# 23
#
# 0: 384x640 2 persons, 3 tvs, 1 microwave, 256.0ms
# Speed: 0.0ms preprocess, 256.0ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
# 24
#
# 0: 384x640 2 persons, 3 tvs, 1 microwave, 304.8ms
# Speed: 2.0ms preprocess, 304.8ms inference, 12.3ms postprocess per image at shape (1, 3, 384, 640)
# 25
#
# 0: 384x640 2 persons, 3 tvs, 1 microwave, 395.9ms
# Speed: 5.7ms preprocess, 395.9ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# 26
#
# 0: 384x640 2 persons, 1 sports ball, 3 tvs, 1 microwave, 240.2ms
# Speed: 7.5ms preprocess, 240.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 27
#
# 0: 384x640 2 persons, 1 sports ball, 2 tvs, 1 microwave, 235.4ms
# Speed: 2.5ms preprocess, 235.4ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
# 28
#
# 0: 384x640 2 persons, 1 sports ball, 1 tv, 200.9ms
# Speed: 0.0ms preprocess, 200.9ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# 29
#
# 0: 384x640 2 persons, 1 sports ball, 2 tvs, 1 microwave, 207.7ms
# Speed: 0.0ms preprocess, 207.7ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 30
#
# 0: 384x640 2 persons, 1 sports ball, 2 tvs, 223.4ms
# Speed: 8.5ms preprocess, 223.4ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
# 31
#
# 0: 384x640 2 persons, 1 sports ball, 2 tvs, 207.1ms
# Speed: 8.0ms preprocess, 207.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 60
#
# 0: 384x640 3 persons, 3 tvs, 288.7ms
# Speed: 5.3ms preprocess, 288.7ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
# 61
#
# 0: 384x640 3 persons, 2 tvs, 266.2ms
# Speed: 0.0ms preprocess, 266.2ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# 62
#
# 0: 384x640 2 persons, 2 tvs, 300.4ms
# Speed: 0.0ms preprocess, 300.4ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
# 63
#
# 0: 384x640 3 persons, 2 tvs, 288.9ms
# Speed: 3.6ms preprocess, 288.9ms inference, 7.2ms postprocess per image at shape (1, 3, 384, 640)
# 64
#
# 0: 384x640 2 persons, 2 tvs, 299.3ms
# Speed: 4.8ms preprocess, 299.3ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
# 65
#
# 0: 384x640 2 persons, 2 tvs, 317.5ms
# Speed: 6.6ms preprocess, 317.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 66
#
# 0: 384x640 2 persons, 1 tv, 240.1ms
# Speed: 3.5ms preprocess, 240.1ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
# 67
#
# 0: 384x640 3 persons, 231.9ms
# Speed: 8.0ms preprocess, 231.9ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
# 68
#
# 0: 384x640 3 persons, 3 tvs, 195.7ms
# Speed: 2.0ms preprocess, 195.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# 69
#
# 0: 384x640 2 persons, 3 tvs, 266.4ms
# Speed: 3.2ms preprocess, 266.4ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
# 70
#
# 0: 384x640 3 persons, 2 tvs, 236.7ms
# Speed: 6.5ms preprocess, 236.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 71
#
# 0: 384x640 1 person, 3 tvs, 254.0ms
# Speed: 3.0ms preprocess, 254.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 72
#
# 0: 384x640 1 person, 1 tv, 303.7ms
# Speed: 9.4ms preprocess, 303.7ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
# 73
#
# 0: 384x640 1 person, 2 tvs, 170.8ms
# Speed: 7.8ms preprocess, 170.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 74
#
# 0: 384x640 1 person, 3 tvs, 186.9ms
# Speed: 0.0ms preprocess, 186.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 75
#
# 0: 384x640 1 person, 3 tvs, 133.2ms
# Speed: 0.0ms preprocess, 133.2ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 76
#
# 0: 384x640 1 person, 2 tvs, 133.6ms
# Speed: 4.5ms preprocess, 133.6ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 77
#
# 0: 384x640 1 person, 3 tvs, 191.3ms
# Speed: 1.0ms preprocess, 191.3ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 78
#
# 0: 384x640 2 persons, 3 tvs, 154.0ms
# Speed: 0.0ms preprocess, 154.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 79
#
# 0: 384x640 2 persons, 3 tvs, 133.2ms
# Speed: 2.7ms preprocess, 133.2ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
# 80
#
# 0: 384x640 2 persons, 2 tvs, 140.5ms
# Speed: 0.0ms preprocess, 140.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# 81
#
# 0: 384x640 2 persons, 3 tvs, 281.9ms
# Speed: 9.8ms preprocess, 281.9ms inference, 8.3ms postprocess per image at shape (1, 3, 384, 640)
# 82
#
# 0: 384x640 2 persons, 3 tvs, 295.6ms
# Speed: 7.0ms preprocess, 295.6ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
# 83
#
# 0: 384x640 2 persons, 2 tvs, 274.9ms
# Speed: 1.3ms preprocess, 274.9ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
# 84
#
# 0: 384x640 2 persons, 3 tvs, 289.0ms
# Speed: 8.5ms preprocess, 289.0ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
# 85
#
# 0: 384x640 3 persons, 2 tvs, 225.3ms
# Speed: 10.5ms preprocess, 225.3ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# 86
#
# 0: 384x640 2 persons, 227.8ms
# Speed: 2.2ms preprocess, 227.8ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
# 87
#
# 0: 384x640 2 persons, 3 tvs, 123.2ms
# Speed: 2.9ms preprocess, 123.2ms inference, 7.8ms postprocess per image at shape (1, 3, 384, 640)
# 88
#
# 0: 384x640 2 persons, 3 tvs, 181.6ms
# Speed: 3.5ms preprocess, 181.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 89
#
# 0: 384x640 2 persons, 4 tvs, 303.0ms
# Speed: 2.6ms preprocess, 303.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 12123
#
# 0: 384x640 2 persons, 123.1ms
# Speed: 9.9ms preprocess, 123.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 12124
#
# 0: 384x640 2 persons, 155.8ms
# Speed: 0.0ms preprocess, 155.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 12125
#
# 0: 384x640 2 persons, 155.3ms
# Speed: 0.0ms preprocess, 155.3ms inference, 12.5ms postprocess per image at shape (1, 3, 384, 640)
# 12126
#
# 0: 384x640 2 persons, 132.4ms
# Speed: 0.0ms preprocess, 132.4ms inference, 12.2ms postprocess per image at shape (1, 3, 384, 640)
# 12127
#
# 0: 384x640 2 persons, 173.8ms
# Speed: 1.8ms preprocess, 173.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 12128
#
# 0: 384x640 2 persons, 155.8ms
# Speed: 0.0ms preprocess, 155.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 12129
#
# 0: 384x640 2 persons, 141.8ms
# Speed: 0.0ms preprocess, 141.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 12130
#
# 0: 384x640 2 persons, 155.1ms
# Speed: 2.6ms preprocess, 155.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 12131
#
# 0: 384x640 2 persons, 149.0ms
# Speed: 2.0ms preprocess, 149.0ms inference, 11.3ms postprocess per image at shape (1, 3, 384, 640)
# 12132
#
# 0: 384x640 2 persons, 163.7ms
# Speed: 11.2ms preprocess, 163.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 12133
#
# 0: 384x640 2 persons, 189.5ms
# Speed: 0.0ms preprocess, 189.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 12134
#
# 0: 384x640 2 persons, 141.3ms
# Speed: 2.0ms preprocess, 141.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 12135
#
# 0: 384x640 2 persons, 167.0ms
# Speed: 0.0ms preprocess, 167.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 12136
#
# 0: 384x640 2 persons, 169.5ms
# Speed: 0.0ms preprocess, 169.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 12137
#
# 0: 384x640 2 persons, 137.7ms
# Speed: 1.9ms preprocess, 137.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 12138
#
# 0: 384x640 2 persons, 121.7ms
# Speed: 9.9ms preprocess, 121.7ms inference, 10.6ms postprocess per image at shape (1, 3, 384, 640)
# 12139
#
# 0: 384x640 2 persons, 144.5ms
# Speed: 4.1ms preprocess, 144.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 12140
#
# 0: 384x640 2 persons, 144.0ms
# Speed: 3.0ms preprocess, 144.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 12141
#
# 0: 384x640 2 persons, 135.0ms
# Speed: 2.0ms preprocess, 135.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 12142

# %%
# import os
# from PIL import Image

# def is_image_corrupted(file_path):
#     try:
#         with Image.open(file_path) as img:
#             img.verify()  # Verify if the image can be opened and is not corrupted
#         return False
#     except (IOError, SyntaxError) as e:
#         return True

# def find_corrupted_files(directory):
#     corrupted_files = []
#     for root, _, files in os.walk(directory):
#         for file in files:
#             file_path = os.path.join(root, file)
#             if is_image_corrupted(file_path):
#                 corrupted_files.append(file_path)
#     return corrupted_files

# def main():
#     directory = input('C:/Users/alimo/OneDrive/Documents/FRT/YOLO MediaPipe Pose Detection/YOLOv8-Mediapipe-Pose-Detection/Output/Hands_Up')
#     corrupted_files = find_corrupted_files(directory)
#     if corrupted_files:
#         print("Corrupted files found:")
#         for file in corrupted_files:
#             print(file)
#     else:
#         print("No corrupted files found.")

# main()

# %%
# # Get the versions
# opencv_version = cv2.__version__
# ultralytics_version = ultralytics.__version__
# mediapipe_version = mp.__version__

# # Write the versions to a requirements.txt file
# with open('/content/drive/MyDrive/bollogy/requirements.txt', 'w') as f:
#     f.write(f"opencv-python=={opencv_version}\n")
#     f.write(f"ultralytics=={ultralytics_version}\n")
#     f.write(f"mediapipe=={mediapipe_version}\n")
#     f.close()

# print("requirements.txt file has been created with the following content:")
# print(f"opencv-python=={opencv_version}")
# print(f"ultralytics=={ultralytics_version}")
# print(f"mediapipe=={mediapipe_version}")
