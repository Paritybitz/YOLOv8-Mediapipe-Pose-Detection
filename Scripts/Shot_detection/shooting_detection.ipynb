# %%
import cv2
import os
from ultralytics import YOLO
import mediapipe as mp
import xml.etree.ElementTree as ET
import string
import random

# %%
# Load YOLOv8 model
model_path = 'yolov8n.pt'  # Using a pre-trained YOLOv8 model
model = YOLO(model_path)

# Initialize MediaPipe Pose
mp_pose = mp.solutions.pose
pose = mp_pose.Pose(static_image_mode=True, model_complexity=2, enable_segmentation=False, min_detection_confidence=0.5)

# %%
# Directory to save results
bbox_output_dir = 'C:/Users/alimo/OneDrive/Documents/FRT/YOLO MediaPipe Pose Detection/YOLOv8-Mediapipe-Pose-Detection/Output/Detected_Bbox'
Handsup_output_dir = 'C:/Users/alimo/OneDrive/Documents/FRT/YOLO MediaPipe Pose Detection/YOLOv8-Mediapipe-Pose-Detection/Output/Hands_Up'
xml_dir = 'C:/Users/alimo/OneDrive/Documents/FRT/YOLO MediaPipe Pose Detection/YOLOv8-Mediapipe-Pose-Detection/Output/XML_Files'

video_dir = 'C:/Users/alimo/OneDrive/Documents/FRT/YOLO MediaPipe Pose Detection/YOLOv8-Mediapipe-Pose-Detection/Videos_data'  # Update with video path

os.makedirs(Handsup_output_dir, exist_ok=True)
os.makedirs(xml_dir, exist_ok=True)
os.makedirs(bbox_output_dir, exist_ok=True)

# Confidence threshold
confidence_threshold = 0.5

# %%
def get_pose_landmarks(image):
    results = pose.process(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    if results.pose_landmarks:
        keypoints = [landmark for landmark in results.pose_landmarks.landmark if landmark.visibility > confidence_threshold]
        if len(keypoints) > len(results.pose_landmarks.landmark) / 2:
            return results.pose_landmarks
    return None

# %%
def classify_pose(landmarks):
    if not landmarks:
        return "No pose detected"

    landmarks_list = [landmark for landmark in landmarks.landmark]

    left_wrist = landmarks_list[mp_pose.PoseLandmark.LEFT_WRIST.value]
    right_wrist = landmarks_list[mp_pose.PoseLandmark.RIGHT_WRIST.value]
    left_eye = landmarks_list[mp_pose.PoseLandmark.LEFT_EYE.value]
    right_eye = landmarks_list[mp_pose.PoseLandmark.RIGHT_EYE.value]
    nose = landmarks_list[mp_pose.PoseLandmark.NOSE.value]

    # Check if either wrist is above the eyes or nose
    if (left_wrist.y < left_eye.y or left_wrist.y < nose.y) and (right_wrist.y < right_eye.y or right_wrist.y < nose.y):
        return "Hands Up"
    else:
        return "Other Pose"

# %%
def create_xml_for_bounding_box(bounding_box, file_name, save_directory):
    """
    Create an XML file for a given bounding box and file name, and save it to the specified directory.

    Parameters:
    bounding_box (tuple): A tuple containing (xmin, ymin, xmax, ymax).
    file_name (str): The name of the file (without extension).
    save_directory (str): The directory where the XML file will be saved.

    Returns:
    str: The name of the created XML file.
    """
    # Ensure the save directory exists
    os.makedirs(save_directory, exist_ok=True)

    # Define the root element
    annotation = ET.Element('annotation')

    # Define the folder element
    folder = ET.SubElement(annotation, 'folder')
    folder.text = 'images'

    # Define the filename element
    filename = ET.SubElement(annotation, 'filename')
    filename.text = f"{file_name}.jpg"

    # Define the path element
    path = ET.SubElement(annotation, 'path')
    path.text = os.path.join('Output\XML_Files', f"{file_name}.jpg")

    # Define the source element
    source = ET.SubElement(annotation, 'source')
    database = ET.SubElement(source, 'database')
    database.text = 'Unknown'

    # Define the size element
    size = ET.SubElement(annotation, 'size')
    width = ET.SubElement(size, 'width')
    width.text = '1280'  # Placeholder value
    height = ET.SubElement(size, 'height')
    height.text = '720'  # Placeholder value
    depth = ET.SubElement(size, 'depth')
    depth.text = '3'  # Assuming RGB images

    # Define the segmented element
    segmented = ET.SubElement(annotation, 'segmented')
    segmented.text = '0'

    # Define the object element
    obj = ET.SubElement(annotation, 'object')
    name = ET.SubElement(obj, 'name')
    name.text = 'shooting player'
    pose = ET.SubElement(obj, 'pose')
    pose.text = 'Unspecified'
    truncated = ET.SubElement(obj, 'truncated')
    truncated.text = '0'
    difficult = ET.SubElement(obj, 'difficult')
    difficult.text = '0'
    bndbox = ET.SubElement(obj, 'bndbox')
    xmin = ET.SubElement(bndbox, 'xmin')
    xmin.text = str(int(bounding_box[0]))
    ymin = ET.SubElement(bndbox, 'ymin')
    ymin.text = str(int(bounding_box[1]))
    xmax = ET.SubElement(bndbox, 'xmax')
    xmax.text = str(int(bounding_box[2]))
    ymax = ET.SubElement(bndbox, 'ymax')
    ymax.text = str(int(bounding_box[3]))

    # Convert the tree to a string and write it to a file
    tree = ET.ElementTree(annotation)
    xml_file_name = os.path.join(save_directory, f"{file_name}.xml")
    tree.write(xml_file_name)

# %%
def detect_person(model, frame):
    results = model.predict(frame)
    detected_persons = []

    for result in results:
        boxes = result.boxes.xyxy.cpu().numpy()
        scores = result.boxes.conf.cpu().numpy()
        class_ids = result.boxes.cls.cpu().numpy()

        for box, score, class_id in zip(boxes, scores, class_ids):
            if class_id == 0 and score > confidence_threshold:  # Class 0 is 'person' in COCO dataset
                x1, y1, x2, y2 = map(int, box)
                height = y2 - y1
                width = x2 - x1
                center_x = (x1 + x2) // 2
                x1 = center_x - height // 2
                x2 = center_x + height // 2
                x1 = max(0, x1)
                x2 = min(frame.shape[1], x2)
                cropped_person = frame[y1:y2, x1:x2]
                landmarks = get_pose_landmarks(cropped_person)
                pose_label = classify_pose(landmarks)
                if pose_label == "Hands Up":
                    print('Hands UP')
                    detected_persons.append((box, score, class_id, pose_label))
    return detected_persons

# %%
def generate_random_name(length=8):
    """ Generate a random string of letters and digits.
    """
    chars = string.ascii_letters + string.digits
    return ''.join(random.choice(chars) for _ in range(length))

# %%
def video_proscessor():
    # Process each video
    frame_counter = 0
    count=0

    for video_file in os.listdir(video_dir):
        if video_file.endswith('.mp4'):
            video_path = os.path.join(video_dir, video_file)
            cap = cv2.VideoCapture(video_path)

            while cap.isOpened():
                ret, frame = cap.read()
                if not ret:
                    break
                count+=1
                detected_persons = detect_person(model, frame)

                for box, score, class_id, pose_label in detected_persons:
                    
                    file_name = f'{generate_random_name()}.jpg'
                    file_path = os.path.join(Handsup_output_dir,file_name)
                    cv2.imwrite(file_path, frame)
                    
                    x1, y1, x2, y2 = map(int, box)
                    cv2.rectangle(frame, (x1, y1), (x2, y2), (255, 0, 0), 2)
                    image_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
                    bbox_file_path = os.path.join(bbox_output_dir, file_name)
                    cv2.imwrite(bbox_file_path, image_rgb)

                    # create_pascal_voc_annotation(file_name, frame.shape, bounding_boxes, xml_dir)
                    create_xml_for_bounding_box(box, file_name.replace('.jpg', ''), xml_dir)
                    frame_counter += 1
                print(count)
            cap.release()
# Out:
# 0: 384x640 2 persons, 1 chair, 222.0ms
# Speed: 8.1ms preprocess, 222.0ms inference, 13.5ms postprocess per image at shape (1, 3, 384, 640)
# 1
#
# 0: 384x640 2 persons, 1 chair, 155.7ms
# Speed: 0.0ms preprocess, 155.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 2
#
# 0: 384x640 2 persons, 166.1ms
# Speed: 0.0ms preprocess, 166.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 3
#
# 0: 384x640 2 persons, 147.4ms
# Speed: 7.0ms preprocess, 147.4ms inference, 7.7ms postprocess per image at shape (1, 3, 384, 640)
# 4
#
# 0: 384x640 2 persons, 167.6ms
# Speed: 0.0ms preprocess, 167.6ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
# 5
#
# 0: 384x640 2 persons, 156.7ms
# Speed: 0.0ms preprocess, 156.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 6
#
# 0: 384x640 2 persons, 152.7ms
# Speed: 0.0ms preprocess, 152.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 7
#
# 0: 384x640 2 persons, 145.6ms
# Speed: 0.0ms preprocess, 145.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 8
#
# 0: 384x640 2 persons, 153.1ms
# Speed: 0.0ms preprocess, 153.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# 9
#
# 0: 384x640 2 persons, 144.4ms
# Speed: 0.0ms preprocess, 144.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 10
#
# 0: 384x640 2 persons, 144.4ms
# Speed: 8.9ms preprocess, 144.4ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# 11
#
# 0: 384x640 2 persons, 137.0ms
# Speed: 9.4ms preprocess, 137.0ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
# 12
#
# 0: 384x640 2 persons, 145.6ms
# Speed: 0.0ms preprocess, 145.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 13
#
# 0: 384x640 2 persons, 151.4ms
# Speed: 0.0ms preprocess, 151.4ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
# 14
#
# 0: 384x640 2 persons, 146.0ms
# Speed: 2.0ms preprocess, 146.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 15
#
# 0: 384x640 2 persons, 142.8ms
# Speed: 3.2ms preprocess, 142.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 16
#
# 0: 384x640 2 persons, 145.4ms
# Speed: 1.0ms preprocess, 145.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 17
#
# 0: 384x640 2 persons, 149.6ms
# Speed: 0.0ms preprocess, 149.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 18
#
# 0: 384x640 2 persons, 165.6ms
# Speed: 0.0ms preprocess, 165.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 19
#
# 0: 384x640 2 persons, 135.5ms
# Speed: 2.5ms preprocess, 135.5ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
# 20
#
# 0: 384x640 2 persons, 142.5ms
# Speed: 2.0ms preprocess, 142.5ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
# 21
#
# 0: 384x640 2 persons, 155.4ms
# Speed: 2.0ms preprocess, 155.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 22
#
# 0: 384x640 4 persons, 1 traffic light, 136.2ms
# Speed: 2.0ms preprocess, 136.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 23
#
# 0: 384x640 3 persons, 151.9ms
# Speed: 1.2ms preprocess, 151.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 24
#
# 0: 384x640 3 persons, 131.8ms
# Speed: 2.5ms preprocess, 131.8ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# 25
#
# 0: 384x640 3 persons, 184.9ms
# Speed: 0.0ms preprocess, 184.9ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
# 26
#
# 0: 384x640 3 persons, 166.3ms
# Speed: 2.0ms preprocess, 166.3ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# 27
#
# 0: 384x640 3 persons, 148.5ms
# Speed: 1.8ms preprocess, 148.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 28
#
# 0: 384x640 3 persons, 163.7ms
# Speed: 0.0ms preprocess, 163.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 29
#
# 0: 384x640 3 persons, 166.8ms
# Speed: 1.1ms preprocess, 166.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 30
#
# 0: 384x640 3 persons, 1 chair, 134.5ms
# Speed: 2.0ms preprocess, 134.5ms inference, 18.2ms postprocess per image at shape (1, 3, 384, 640)
# 31
#
# 0: 384x640 3 persons, 1 chair, 160.8ms
# Speed: 0.9ms preprocess, 160.8ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
# 32
#
# 0: 384x640 3 persons, 1 chair, 133.2ms
# Speed: 1.6ms preprocess, 133.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 33
#
# 0: 384x640 3 persons, 1 chair, 168.9ms
# Speed: 1.6ms preprocess, 168.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 34
#
# 0: 384x640 3 persons, 1 chair, 160.1ms
# Speed: 2.0ms preprocess, 160.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 35
#
# 0: 384x640 3 persons, 1 chair, 139.6ms
# Speed: 1.5ms preprocess, 139.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 36
#
# 0: 384x640 3 persons, 1 chair, 140.4ms
# Speed: 5.0ms preprocess, 140.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# 37
#
# 0: 384x640 3 persons, 1 chair, 142.7ms
# Speed: 1.8ms preprocess, 142.7ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# 38
#
# 0: 384x640 3 persons, 1 chair, 136.7ms
# Speed: 2.0ms preprocess, 136.7ms inference, 12.2ms postprocess per image at shape (1, 3, 384, 640)
# 39
#
# 0: 384x640 3 persons, 1 chair, 136.5ms
# Speed: 4.0ms preprocess, 136.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 40
#
# 0: 384x640 3 persons, 1 chair, 152.4ms
# Speed: 2.0ms preprocess, 152.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 41
#
# 0: 384x640 3 persons, 149.6ms
# Speed: 0.0ms preprocess, 149.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# 42
#
# 0: 384x640 3 persons, 132.5ms
# Speed: 2.0ms preprocess, 132.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 43
#
# 0: 384x640 3 persons, 143.6ms
# Speed: 2.0ms preprocess, 143.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 44
#
# 0: 384x640 3 persons, 153.8ms
# Speed: 4.8ms preprocess, 153.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 45
#
# 0: 384x640 3 persons, 171.6ms
# Speed: 3.0ms preprocess, 171.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 46
#
# 0: 384x640 3 persons, 152.7ms
# Speed: 2.0ms preprocess, 152.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 47
#
# 0: 384x640 3 persons, 142.6ms
# Speed: 2.0ms preprocess, 142.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 48
#
# 0: 384x640 3 persons, 138.0ms
# Speed: 1.1ms preprocess, 138.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# 49
#
# 0: 384x640 3 persons, 158.8ms
# Speed: 0.0ms preprocess, 158.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 50
#
# 0: 384x640 3 persons, 167.1ms
# Speed: 2.0ms preprocess, 167.1ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
# 51
#
# 0: 384x640 3 persons, 135.9ms
# Speed: 2.0ms preprocess, 135.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 52
#
# 0: 384x640 3 persons, 138.3ms
# Speed: 2.0ms preprocess, 138.3ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
# 53
#
# 0: 384x640 3 persons, 140.8ms
# Speed: 0.0ms preprocess, 140.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 54
#
# 0: 384x640 3 persons, 155.7ms
# Speed: 5.4ms preprocess, 155.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 55
#
# 0: 384x640 3 persons, 192.9ms
# Speed: 0.0ms preprocess, 192.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 56
#
# 0: 384x640 3 persons, 146.5ms
# Speed: 1.2ms preprocess, 146.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 57
#
# 0: 384x640 3 persons, 135.5ms
# Speed: 2.0ms preprocess, 135.5ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
# 58
#
# 0: 384x640 3 persons, 169.8ms
# Speed: 1.1ms preprocess, 169.8ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# 59
#
# 0: 384x640 3 persons, 176.8ms
# Speed: 4.9ms preprocess, 176.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 60
#
# 0: 384x640 3 persons, 139.2ms
# Speed: 2.0ms preprocess, 139.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 61
#
# 0: 384x640 3 persons, 191.1ms
# Speed: 3.6ms preprocess, 191.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 62
#
# 0: 384x640 3 persons, 147.7ms
# Speed: 0.0ms preprocess, 147.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 63
#
# 0: 384x640 3 persons, 1 handbag, 133.3ms
# Speed: 0.0ms preprocess, 133.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 64
#
# 0: 384x640 3 persons, 127.7ms
# Speed: 2.0ms preprocess, 127.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 65
#
# 0: 384x640 4 persons, 153.6ms
# Speed: 2.0ms preprocess, 153.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 66
#
# 0: 384x640 3 persons, 146.1ms
# Speed: 2.4ms preprocess, 146.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 67
#
# 0: 384x640 3 persons, 143.7ms
# Speed: 2.0ms preprocess, 143.7ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# 68
#
# 0: 384x640 3 persons, 146.4ms
# Speed: 1.3ms preprocess, 146.4ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 69
#
# 0: 384x640 3 persons, 138.5ms
# Speed: 1.0ms preprocess, 138.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 70
#
# 0: 384x640 3 persons, 134.5ms
# Speed: 3.0ms preprocess, 134.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 71
#
# 0: 384x640 3 persons, 149.4ms
# Speed: 2.0ms preprocess, 149.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 72
#
# 0: 384x640 3 persons, 171.2ms
# Speed: 11.9ms preprocess, 171.2ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 73
#
# 0: 384x640 3 persons, 141.3ms
# Speed: 3.2ms preprocess, 141.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 74
#
# 0: 384x640 3 persons, 133.8ms
# Speed: 2.0ms preprocess, 133.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 75
#
# 0: 384x640 3 persons, 133.0ms
# Speed: 0.0ms preprocess, 133.0ms inference, 13.3ms postprocess per image at shape (1, 3, 384, 640)
# 76
#
# 0: 384x640 3 persons, 156.6ms
# Speed: 3.5ms preprocess, 156.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 77
#
# 0: 384x640 3 persons, 163.9ms
# Speed: 0.0ms preprocess, 163.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 78
#
# 0: 384x640 3 persons, 160.9ms
# Speed: 1.5ms preprocess, 160.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 79
#
# 0: 384x640 3 persons, 142.2ms
# Speed: 2.0ms preprocess, 142.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 80
#
# 0: 384x640 3 persons, 148.2ms
# Speed: 2.4ms preprocess, 148.2ms inference, 12.2ms postprocess per image at shape (1, 3, 384, 640)
# 81
#
# 0: 384x640 3 persons, 198.5ms
# Speed: 1.0ms preprocess, 198.5ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# 82
#
# 0: 384x640 4 persons, 407.7ms
# Speed: 0.0ms preprocess, 407.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 83
#
# 0: 384x640 3 persons, 393.6ms
# Speed: 0.0ms preprocess, 393.6ms inference, 15.7ms postprocess per image at shape (1, 3, 384, 640)
# 84
#
# 0: 384x640 3 persons, 455.3ms
# Speed: 0.0ms preprocess, 455.3ms inference, 15.7ms postprocess per image at shape (1, 3, 384, 640)
# 85
#
# 0: 384x640 3 persons, 423.5ms
# Speed: 0.0ms preprocess, 423.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 86
#
# 0: 384x640 3 persons, 247.8ms
# Speed: 15.6ms preprocess, 247.8ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
# 87
#
# 0: 384x640 3 persons, 219.8ms
# Speed: 0.0ms preprocess, 219.8ms inference, 16.7ms postprocess per image at shape (1, 3, 384, 640)
# 88
#
# 0: 384x640 3 persons, 409.1ms
# Speed: 0.0ms preprocess, 409.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 89
#
# 0: 384x640 3 persons, 488.2ms
# Speed: 0.0ms preprocess, 488.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 90
#
# 0: 384x640 3 persons, 156.3ms
# Speed: 0.0ms preprocess, 156.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 91
#
# 0: 384x640 3 persons, 1 chair, 484.4ms
# Speed: 0.0ms preprocess, 484.4ms inference, 15.7ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 92
#
# 0: 384x640 3 persons, 236.5ms
# Speed: 0.0ms preprocess, 236.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 93
#
# 0: 384x640 3 persons, 1 chair, 313.6ms
# Speed: 0.0ms preprocess, 313.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 94
#
# 0: 384x640 3 persons, 1 chair, 376.8ms
# Speed: 0.0ms preprocess, 376.8ms inference, 19.4ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 95
#
# 0: 384x640 3 persons, 1 chair, 441.0ms
# Speed: 15.6ms preprocess, 441.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 96
#
# 0: 384x640 3 persons, 1 chair, 471.8ms
# Speed: 0.0ms preprocess, 471.8ms inference, 21.4ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 97
#
# 0: 384x640 3 persons, 1 chair, 332.2ms
# Speed: 15.6ms preprocess, 332.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 98
#
# 0: 384x640 3 persons, 1 chair, 423.9ms
# Speed: 0.0ms preprocess, 423.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 99
#
# 0: 384x640 3 persons, 1 chair, 438.0ms
# Speed: 12.1ms preprocess, 438.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 100
#
# 0: 384x640 3 persons, 1 chair, 393.8ms
# Speed: 15.7ms preprocess, 393.8ms inference, 16.1ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 101
#
# 0: 384x640 3 persons, 1 chair, 535.8ms
# Speed: 0.0ms preprocess, 535.8ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 102
#
# 0: 384x640 3 persons, 1 chair, 519.0ms
# Speed: 0.0ms preprocess, 519.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 103
#
# 0: 384x640 3 persons, 1 chair, 377.9ms
# Speed: 0.0ms preprocess, 377.9ms inference, 23.2ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 104
#
# 0: 384x640 3 persons, 1 chair, 390.0ms
# Speed: 0.0ms preprocess, 390.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 105
#
# 0: 384x640 3 persons, 441.4ms
# Speed: 15.6ms preprocess, 441.4ms inference, 15.7ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 106
#
# 0: 384x640 3 persons, 422.6ms
# Speed: 0.0ms preprocess, 422.6ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 107
#
# 0: 384x640 3 persons, 631.0ms
# Speed: 6.1ms preprocess, 631.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 108
#
# 0: 384x640 3 persons, 509.9ms
# Speed: 15.7ms preprocess, 509.9ms inference, 10.6ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 109
#
# 0: 384x640 3 persons, 487.8ms
# Speed: 15.7ms preprocess, 487.8ms inference, 15.7ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 110
#
# 0: 384x640 3 persons, 394.6ms
# Speed: 15.7ms preprocess, 394.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 111
#
# 0: 384x640 3 persons, 678.7ms
# Speed: 15.7ms preprocess, 678.7ms inference, 30.4ms postprocess per image at shape (1, 3, 384, 640)
# 112
#
# 0: 384x640 3 persons, 392.7ms
# Speed: 0.0ms preprocess, 392.7ms inference, 15.7ms postprocess per image at shape (1, 3, 384, 640)
# 113
#
# 0: 384x640 3 persons, 598.4ms
# Speed: 0.0ms preprocess, 598.4ms inference, 15.7ms postprocess per image at shape (1, 3, 384, 640)
# 114
#
# 0: 384x640 3 persons, 504.2ms
# Speed: 0.0ms preprocess, 504.2ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
# 115
#
# 0: 384x640 4 persons, 424.7ms
# Speed: 15.6ms preprocess, 424.7ms inference, 15.5ms postprocess per image at shape (1, 3, 384, 640)
# 116
#
# 0: 384x640 3 persons, 518.0ms
# Speed: 0.0ms preprocess, 518.0ms inference, 15.7ms postprocess per image at shape (1, 3, 384, 640)
# 117
#
# 0: 384x640 3 persons, 425.7ms
# Speed: 15.7ms preprocess, 425.7ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
# 118
#
# 0: 384x640 4 persons, 471.7ms
# Speed: 4.0ms preprocess, 471.7ms inference, 20.1ms postprocess per image at shape (1, 3, 384, 640)
# 119
#
# 0: 384x640 4 persons, 709.5ms
# Speed: 0.0ms preprocess, 709.5ms inference, 39.4ms postprocess per image at shape (1, 3, 384, 640)
# 120
#
# 0: 384x640 4 persons, 472.0ms
# Speed: 3.1ms preprocess, 472.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 121
#
# 0: 384x640 4 persons, 406.0ms
# Speed: 3.7ms preprocess, 406.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 122
#
# 0: 384x640 3 persons, 645.9ms
# Speed: 0.0ms preprocess, 645.9ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
# 123
#
# 0: 384x640 3 persons, 363.0ms
# Speed: 0.0ms preprocess, 363.0ms inference, 22.8ms postprocess per image at shape (1, 3, 384, 640)
# 124
#
# 0: 384x640 3 persons, 415.5ms
# Speed: 10.0ms preprocess, 415.5ms inference, 15.7ms postprocess per image at shape (1, 3, 384, 640)
# 125
#
# 0: 384x640 4 persons, 440.3ms
# Speed: 13.1ms preprocess, 440.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 126
#
# 0: 384x640 3 persons, 519.6ms
# Speed: 0.0ms preprocess, 519.6ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
# 127
#
# 0: 384x640 3 persons, 418.9ms
# Speed: 0.0ms preprocess, 418.9ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 640)
# 128
#
# 0: 384x640 3 persons, 582.1ms
# Speed: 15.8ms preprocess, 582.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 129
#
# 0: 384x640 3 persons, 378.0ms
# Speed: 15.7ms preprocess, 378.0ms inference, 15.7ms postprocess per image at shape (1, 3, 384, 640)
# 130
#
# 0: 384x640 3 persons, 550.8ms
# Speed: 0.0ms preprocess, 550.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 131
#
# 0: 384x640 3 persons, 613.6ms
# Speed: 0.0ms preprocess, 613.6ms inference, 15.5ms postprocess per image at shape (1, 3, 384, 640)
# 132
#
# 0: 384x640 3 persons, 400.8ms
# Speed: 16.8ms preprocess, 400.8ms inference, 8.6ms postprocess per image at shape (1, 3, 384, 640)
# 133
#
# 0: 384x640 4 persons, 503.9ms
# Speed: 0.0ms preprocess, 503.9ms inference, 17.2ms postprocess per image at shape (1, 3, 384, 640)
# 134
#
# 0: 384x640 4 persons, 425.1ms
# Speed: 0.0ms preprocess, 425.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 135
#
# 0: 384x640 4 persons, 405.9ms
# Speed: 0.0ms preprocess, 405.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 136
#
# 0: 384x640 3 persons, 409.3ms
# Speed: 7.0ms preprocess, 409.3ms inference, 15.7ms postprocess per image at shape (1, 3, 384, 640)
# 137
#
# 0: 384x640 3 persons, 1 chair, 508.7ms
# Speed: 0.0ms preprocess, 508.7ms inference, 12.6ms postprocess per image at shape (1, 3, 384, 640)
# 138
#
# 0: 384x640 3 persons, 614.3ms
# Speed: 15.6ms preprocess, 614.3ms inference, 19.0ms postprocess per image at shape (1, 3, 384, 640)
# 139
#
# 0: 384x640 3 persons, 387.0ms
# Speed: 7.1ms preprocess, 387.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 140
#
# 0: 384x640 4 persons, 486.9ms
# Speed: 0.0ms preprocess, 486.9ms inference, 15.7ms postprocess per image at shape (1, 3, 384, 640)
# 141
#
# 0: 384x640 3 persons, 378.7ms
# Speed: 15.6ms preprocess, 378.7ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
# 142
#
# 0: 384x640 3 persons, 362.4ms
# Speed: 15.5ms preprocess, 362.4ms inference, 15.7ms postprocess per image at shape (1, 3, 384, 640)
# 143
#
# 0: 384x640 3 persons, 266.5ms
# Speed: 3.6ms preprocess, 266.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 144
#
# 0: 384x640 3 persons, 677.4ms
# Speed: 15.7ms preprocess, 677.4ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
# 145
#
# 0: 384x640 3 persons, 455.9ms
# Speed: 0.0ms preprocess, 455.9ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
# 146
#
# 0: 384x640 3 persons, 456.6ms
# Speed: 1.1ms preprocess, 456.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 147
#
# 0: 384x640 3 persons, 424.8ms
# Speed: 0.0ms preprocess, 424.8ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
# 148
#
# 0: 384x640 3 persons, 402.8ms
# Speed: 0.0ms preprocess, 402.8ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
# 149
#
# 0: 384x640 3 persons, 424.4ms
# Speed: 0.0ms preprocess, 424.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 150
#
# 0: 384x640 3 persons, 1 chair, 269.9ms
# Speed: 0.0ms preprocess, 269.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 151
#
# 0: 384x640 2 persons, 1 chair, 534.9ms
# Speed: 0.0ms preprocess, 534.9ms inference, 15.7ms postprocess per image at shape (1, 3, 384, 640)
# 152
#
# 0: 384x640 2 persons, 644.8ms
# Speed: 0.0ms preprocess, 644.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 153
#
# 0: 384x640 2 persons, 1 chair, 393.4ms
# Speed: 0.0ms preprocess, 393.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 154
#
# 0: 384x640 2 persons, 456.4ms
# Speed: 15.7ms preprocess, 456.4ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
# 155
#
# 0: 384x640 2 persons, 1 chair, 362.0ms
# Speed: 16.1ms preprocess, 362.0ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
# 156
#
# 0: 384x640 2 persons, 1 chair, 441.5ms
# Speed: 15.6ms preprocess, 441.5ms inference, 18.7ms postprocess per image at shape (1, 3, 384, 640)
# 157
#
# 0: 384x640 4 persons, 1 chair, 456.3ms
# Speed: 0.0ms preprocess, 456.3ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
# 158
#
# 0: 384x640 3 persons, 449.2ms
# Speed: 0.0ms preprocess, 449.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 159
#
# 0: 384x640 3 persons, 424.6ms
# Speed: 0.0ms preprocess, 424.6ms inference, 22.2ms postprocess per image at shape (1, 3, 384, 640)
# 160
#
# 0: 384x640 3 persons, 377.2ms
# Speed: 0.0ms preprocess, 377.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 161
#
# 0: 384x640 3 persons, 440.6ms
# Speed: 0.0ms preprocess, 440.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 162
#
# 0: 384x640 3 persons, 398.4ms
# Speed: 15.6ms preprocess, 398.4ms inference, 9.6ms postprocess per image at shape (1, 3, 384, 640)
# 163
#
# 0: 384x640 2 persons, 1 traffic light, 377.0ms
# Speed: 0.0ms preprocess, 377.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 164
#
# 0: 384x640 3 persons, 471.4ms
# Speed: 0.0ms preprocess, 471.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 165
#
# 0: 384x640 2 persons, 440.5ms
# Speed: 0.0ms preprocess, 440.5ms inference, 15.7ms postprocess per image at shape (1, 3, 384, 640)
# 166
#
# 0: 384x640 2 persons, 392.9ms
# Speed: 15.6ms preprocess, 392.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 167
#
# 0: 384x640 2 persons, 393.8ms
# Speed: 0.0ms preprocess, 393.8ms inference, 15.7ms postprocess per image at shape (1, 3, 384, 640)
# 168
#
# 0: 384x640 2 persons, 144.5ms
# Speed: 0.0ms preprocess, 144.5ms inference, 10.4ms postprocess per image at shape (1, 3, 384, 640)
# 169
#
# 0: 384x640 2 persons, 156.0ms
# Speed: 10.8ms preprocess, 156.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 170
#
# 0: 384x640 2 persons, 1 chair, 146.5ms
# Speed: 3.0ms preprocess, 146.5ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# 171
#
# 0: 384x640 2 persons, 144.4ms
# Speed: 0.0ms preprocess, 144.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 172
#
# 0: 384x640 2 persons, 130.0ms
# Speed: 1.9ms preprocess, 130.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 173
#
# 0: 384x640 2 persons, 137.1ms
# Speed: 0.0ms preprocess, 137.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 174
#
# 0: 384x640 2 persons, 1 chair, 143.9ms
# Speed: 0.0ms preprocess, 143.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 175
#
# 0: 384x640 2 persons, 1 chair, 136.8ms
# Speed: 2.2ms preprocess, 136.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 176
#
# 0: 384x640 2 persons, 1 chair, 147.0ms
# Speed: 1.8ms preprocess, 147.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 177
#
# 0: 384x640 2 persons, 1 chair, 140.2ms
# Speed: 2.1ms preprocess, 140.2ms inference, 12.2ms postprocess per image at shape (1, 3, 384, 640)
# 178
#
# 0: 384x640 2 persons, 1 chair, 144.9ms
# Speed: 2.1ms preprocess, 144.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 179
#
# 0: 384x640 2 persons, 1 chair, 151.0ms
# Speed: 0.0ms preprocess, 151.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# 180
#
# 0: 384x640 2 persons, 1 chair, 140.9ms
# Speed: 3.0ms preprocess, 140.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 181
#
# 0: 384x640 2 persons, 1 chair, 153.0ms
# Speed: 0.0ms preprocess, 153.0ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
# 182
#
# 0: 384x640 2 persons, 1 chair, 168.4ms
# Speed: 2.1ms preprocess, 168.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 183
#
# 0: 384x640 2 persons, 1 chair, 132.3ms
# Speed: 4.2ms preprocess, 132.3ms inference, 15.1ms postprocess per image at shape (1, 3, 384, 640)
# 184
#
# 0: 384x640 2 persons, 1 chair, 133.6ms
# Speed: 10.9ms preprocess, 133.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 185
#
# 0: 384x640 2 persons, 1 chair, 142.7ms
# Speed: 0.0ms preprocess, 142.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# 186
#
# 0: 384x640 2 persons, 1 chair, 141.4ms
# Speed: 1.2ms preprocess, 141.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 187
#
# 0: 384x640 2 persons, 1 chair, 137.9ms
# Speed: 0.0ms preprocess, 137.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 188
#
# 0: 384x640 3 persons, 1 chair, 161.2ms
# Speed: 1.0ms preprocess, 161.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 189
#
# 0: 384x640 2 persons, 1 sports ball, 137.0ms
# Speed: 0.0ms preprocess, 137.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 190
#
# 0: 384x640 2 persons, 1 sports ball, 151.3ms
# Speed: 0.0ms preprocess, 151.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 191
#
# 0: 384x640 2 persons, 136.8ms
# Speed: 10.1ms preprocess, 136.8ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
# 192
#
# 0: 384x640 2 persons, 1 sports ball, 151.5ms
# Speed: 0.0ms preprocess, 151.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 193
#
# 0: 384x640 2 persons, 147.6ms
# Speed: 0.0ms preprocess, 147.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 194
#
# 0: 384x640 2 persons, 1 sports ball, 131.7ms
# Speed: 15.5ms preprocess, 131.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 195
#
# 0: 384x640 2 persons, 1 sports ball, 120.3ms
# Speed: 2.9ms preprocess, 120.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 196
#
# 0: 384x640 2 persons, 1 sports ball, 130.7ms
# Speed: 0.0ms preprocess, 130.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 197
#
# 0: 384x640 2 persons, 1 sports ball, 143.6ms
# Speed: 0.0ms preprocess, 143.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# 198
#
# 0: 384x640 2 persons, 167.9ms
# Speed: 0.0ms preprocess, 167.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 199
#
# 0: 384x640 2 persons, 142.7ms
# Speed: 0.0ms preprocess, 142.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 200
#
# 0: 384x640 2 persons, 133.4ms
# Speed: 1.5ms preprocess, 133.4ms inference, 11.4ms postprocess per image at shape (1, 3, 384, 640)
# 201
#
# 0: 384x640 2 persons, 1 sports ball, 130.5ms
# Speed: 1.7ms preprocess, 130.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 202
#
# 0: 384x640 2 persons, 1 sports ball, 139.2ms
# Speed: 2.9ms preprocess, 139.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 203
#
# 0: 384x640 2 persons, 130.9ms
# Speed: 0.0ms preprocess, 130.9ms inference, 10.8ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 204
#
# 0: 384x640 2 persons, 154.8ms
# Speed: 2.0ms preprocess, 154.8ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 205
#
# 0: 384x640 2 persons, 144.0ms
# Speed: 1.9ms preprocess, 144.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 206
#
# 0: 384x640 2 persons, 141.4ms
# Speed: 0.0ms preprocess, 141.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 207
#
# 0: 384x640 2 persons, 132.5ms
# Speed: 1.9ms preprocess, 132.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 208
#
# 0: 384x640 2 persons, 154.9ms
# Speed: 0.0ms preprocess, 154.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 209
#
# 0: 384x640 2 persons, 134.6ms
# Speed: 5.3ms preprocess, 134.6ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
# 210
#
# 0: 384x640 2 persons, 140.6ms
# Speed: 2.0ms preprocess, 140.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 211
#
# 0: 384x640 2 persons, 129.0ms
# Speed: 4.4ms preprocess, 129.0ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
# 212
#
# 0: 384x640 2 persons, 161.6ms
# Speed: 2.0ms preprocess, 161.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 213
#
# 0: 384x640 2 persons, 151.8ms
# Speed: 0.0ms preprocess, 151.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 214
#
# 0: 384x640 2 persons, 133.9ms
# Speed: 2.0ms preprocess, 133.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 215
#
# 0: 384x640 2 persons, 147.5ms
# Speed: 0.0ms preprocess, 147.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 216
#
# 0: 384x640 2 persons, 128.7ms
# Speed: 4.7ms preprocess, 128.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 217
#
# 0: 384x640 2 persons, 144.6ms
# Speed: 0.0ms preprocess, 144.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# 218
#
# 0: 384x640 2 persons, 133.4ms
# Speed: 1.8ms preprocess, 133.4ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
# 219
#
# 0: 384x640 2 persons, 171.2ms
# Speed: 2.1ms preprocess, 171.2ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 220
#
# 0: 384x640 2 persons, 147.6ms
# Speed: 2.1ms preprocess, 147.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# 221
#
# 0: 384x640 2 persons, 140.8ms
# Speed: 4.0ms preprocess, 140.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 222
#
# 0: 384x640 2 persons, 136.5ms
# Speed: 1.9ms preprocess, 136.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 223
#
# 0: 384x640 2 persons, 131.3ms
# Speed: 2.0ms preprocess, 131.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# 224
#
# 0: 384x640 2 persons, 140.7ms
# Speed: 1.9ms preprocess, 140.7ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
# 225
#
# 0: 384x640 2 persons, 152.3ms
# Speed: 2.4ms preprocess, 152.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 226
#
# 0: 384x640 2 persons, 131.3ms
# Speed: 0.0ms preprocess, 131.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 227
#
# 0: 384x640 2 persons, 162.7ms
# Speed: 2.0ms preprocess, 162.7ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
# 228
#
# 0: 384x640 2 persons, 137.9ms
# Speed: 1.9ms preprocess, 137.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 229
#
# 0: 384x640 2 persons, 132.1ms
# Speed: 2.0ms preprocess, 132.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 230
#
# 0: 384x640 2 persons, 156.5ms
# Speed: 3.3ms preprocess, 156.5ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
# 231
#
# 0: 384x640 2 persons, 175.4ms
# Speed: 12.2ms preprocess, 175.4ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 232
#
# 0: 384x640 2 persons, 154.1ms
# Speed: 1.9ms preprocess, 154.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 233
#
# 0: 384x640 2 persons, 153.1ms
# Speed: 2.1ms preprocess, 153.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# 234
#
# 0: 384x640 2 persons, 150.3ms
# Speed: 1.9ms preprocess, 150.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 235
#
# 0: 384x640 2 persons, 139.4ms
# Speed: 2.0ms preprocess, 139.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 236
#
# 0: 384x640 2 persons, 169.4ms
# Speed: 2.0ms preprocess, 169.4ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
# 237
#
# 0: 384x640 3 persons, 151.3ms
# Speed: 2.0ms preprocess, 151.3ms inference, 11.3ms postprocess per image at shape (1, 3, 384, 640)
# 238
#
# 0: 384x640 2 persons, 142.3ms
# Speed: 2.0ms preprocess, 142.3ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
# 239
#
# 0: 384x640 2 persons, 136.9ms
# Speed: 2.5ms preprocess, 136.9ms inference, 11.1ms postprocess per image at shape (1, 3, 384, 640)
# 240
#
# 0: 384x640 2 persons, 160.8ms
# Speed: 2.0ms preprocess, 160.8ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 241
#
# 0: 384x640 2 persons, 146.3ms
# Speed: 2.1ms preprocess, 146.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 242
#
# 0: 384x640 2 persons, 153.5ms
# Speed: 2.1ms preprocess, 153.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 243
#
# 0: 384x640 2 persons, 140.6ms
# Speed: 2.0ms preprocess, 140.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 244
#
# 0: 384x640 2 persons, 154.2ms
# Speed: 6.1ms preprocess, 154.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 245
#
# 0: 384x640 2 persons, 159.7ms
# Speed: 1.9ms preprocess, 159.7ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
# 246
#
# 0: 384x640 2 persons, 164.8ms
# Speed: 2.0ms preprocess, 164.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 247
#
# 0: 384x640 2 persons, 142.4ms
# Speed: 2.0ms preprocess, 142.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# 248
#
# 0: 384x640 2 persons, 143.5ms
# Speed: 2.8ms preprocess, 143.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 249
#
# 0: 384x640 2 persons, 166.6ms
# Speed: 1.1ms preprocess, 166.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 250
#
# 0: 384x640 2 persons, 150.6ms
# Speed: 2.0ms preprocess, 150.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 251
#
# 0: 384x640 2 persons, 172.9ms
# Speed: 5.7ms preprocess, 172.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 252
#
# 0: 384x640 2 persons, 138.8ms
# Speed: 2.0ms preprocess, 138.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 253
#
# 0: 384x640 2 persons, 147.7ms
# Speed: 3.7ms preprocess, 147.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# 254
#
# 0: 384x640 2 persons, 148.6ms
# Speed: 1.4ms preprocess, 148.6ms inference, 11.6ms postprocess per image at shape (1, 3, 384, 640)
# 255
#
# 0: 384x640 2 persons, 147.3ms
# Speed: 0.0ms preprocess, 147.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 256
#
# 0: 384x640 2 persons, 154.6ms
# Speed: 2.8ms preprocess, 154.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 257
#
# 0: 384x640 2 persons, 137.7ms
# Speed: 1.0ms preprocess, 137.7ms inference, 12.3ms postprocess per image at shape (1, 3, 384, 640)
# 258
#
# 0: 384x640 2 persons, 133.4ms
# Speed: 3.0ms preprocess, 133.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 259
#
# 0: 384x640 2 persons, 191.3ms
# Speed: 4.5ms preprocess, 191.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 260
#
# 0: 384x640 2 persons, 135.3ms
# Speed: 2.8ms preprocess, 135.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 261
#
# 0: 384x640 2 persons, 133.7ms
# Speed: 2.0ms preprocess, 133.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 262
#
# 0: 384x640 2 persons, 138.0ms
# Speed: 2.0ms preprocess, 138.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 263
#
# 0: 384x640 2 persons, 173.8ms
# Speed: 1.0ms preprocess, 173.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 264
#
# 0: 384x640 2 persons, 142.9ms
# Speed: 0.0ms preprocess, 142.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 265
#
# 0: 384x640 2 persons, 133.7ms
# Speed: 2.0ms preprocess, 133.7ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# 266
#
# 0: 384x640 2 persons, 152.8ms
# Speed: 0.0ms preprocess, 152.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 267
#
# 0: 384x640 2 persons, 141.1ms
# Speed: 2.0ms preprocess, 141.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# 268
#
# 0: 384x640 3 persons, 137.1ms
# Speed: 2.0ms preprocess, 137.1ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
# 269
#
# 0: 384x640 3 persons, 132.8ms
# Speed: 0.0ms preprocess, 132.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 270
#
# 0: 384x640 3 persons, 173.9ms
# Speed: 2.7ms preprocess, 173.9ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# 271
#
# 0: 384x640 2 persons, 151.1ms
# Speed: 2.4ms preprocess, 151.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 272
#
# 0: 384x640 3 persons, 119.9ms
# Speed: 2.0ms preprocess, 119.9ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
# 273
#
# 0: 384x640 3 persons, 144.6ms
# Speed: 9.2ms preprocess, 144.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 274
#
# 0: 384x640 2 persons, 131.9ms
# Speed: 1.0ms preprocess, 131.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 275
#
# 0: 384x640 2 persons, 139.9ms
# Speed: 1.3ms preprocess, 139.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 276
#
# 0: 384x640 2 persons, 130.6ms
# Speed: 0.0ms preprocess, 130.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 277
#
# 0: 384x640 2 persons, 151.0ms
# Speed: 11.5ms preprocess, 151.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# 278
#
# 0: 384x640 2 persons, 168.3ms
# Speed: 1.1ms preprocess, 168.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# 279
#
# 0: 384x640 2 persons, 150.8ms
# Speed: 0.0ms preprocess, 150.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 280
#
# 0: 384x640 2 persons, 185.9ms
# Speed: 12.1ms preprocess, 185.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# 281
#
# 0: 384x640 2 persons, 163.5ms
# Speed: 2.3ms preprocess, 163.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 282
#
# 0: 384x640 2 persons, 143.6ms
# Speed: 4.4ms preprocess, 143.6ms inference, 13.7ms postprocess per image at shape (1, 3, 384, 640)
# 283
#
# 0: 384x640 2 persons, 182.4ms
# Speed: 0.0ms preprocess, 182.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 284
#
# 0: 384x640 2 persons, 155.2ms
# Speed: 2.0ms preprocess, 155.2ms inference, 11.2ms postprocess per image at shape (1, 3, 384, 640)
# 285
#
# 0: 384x640 2 persons, 197.3ms
# Speed: 1.4ms preprocess, 197.3ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# 286
#
# 0: 384x640 2 persons, 629.9ms
# Speed: 2.0ms preprocess, 629.9ms inference, 18.2ms postprocess per image at shape (1, 3, 384, 640)
# 287
#
# 0: 384x640 2 persons, 217.9ms
# Speed: 3.0ms preprocess, 217.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 288
#
# 0: 384x640 2 persons, 196.5ms
# Speed: 2.0ms preprocess, 196.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 289
#
# 0: 384x640 2 persons, 194.2ms
# Speed: 3.0ms preprocess, 194.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 290
#
# 0: 384x640 2 persons, 182.3ms
# Speed: 0.0ms preprocess, 182.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 291
#
# 0: 384x640 2 persons, 172.0ms
# Speed: 1.0ms preprocess, 172.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# 292
#
# 0: 384x640 2 persons, 146.5ms
# Speed: 2.0ms preprocess, 146.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 293
#
# 0: 384x640 2 persons, 189.2ms
# Speed: 1.0ms preprocess, 189.2ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
# 294
#
# 0: 384x640 2 persons, 169.8ms
# Speed: 1.8ms preprocess, 169.8ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# 295
#
# 0: 384x640 2 persons, 190.1ms
# Speed: 3.1ms preprocess, 190.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 296
#
# 0: 384x640 2 persons, 140.9ms
# Speed: 3.6ms preprocess, 140.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 297
#
# 0: 384x640 2 persons, 226.4ms
# Speed: 2.1ms preprocess, 226.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 298
#
# 0: 384x640 2 persons, 313.6ms
# Speed: 0.7ms preprocess, 313.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 299
#
# 0: 384x640 1 person, 153.1ms
# Speed: 1.0ms preprocess, 153.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 300
#
# 0: 384x640 1 person, 159.5ms
# Speed: 2.0ms preprocess, 159.5ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
# 301
#
# 0: 384x640 1 person, 140.6ms
# Speed: 1.9ms preprocess, 140.6ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
# 302
#
# 0: 384x640 1 person, 133.6ms
# Speed: 0.0ms preprocess, 133.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 303
#
# 0: 384x640 1 person, 188.7ms
# Speed: 2.0ms preprocess, 188.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 304
#
# 0: 384x640 1 person, 142.8ms
# Speed: 1.8ms preprocess, 142.8ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# 305
#
# 0: 384x640 3 persons, 140.5ms
# Speed: 3.1ms preprocess, 140.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 306
#
# 0: 384x640 2 persons, 147.0ms
# Speed: 2.1ms preprocess, 147.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 307
#
# 0: 384x640 2 persons, 141.7ms
# Speed: 0.9ms preprocess, 141.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 308
#
# 0: 384x640 2 persons, 166.9ms
# Speed: 2.1ms preprocess, 166.9ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 309
#
# 0: 384x640 2 persons, 165.8ms
# Speed: 0.0ms preprocess, 165.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 310
#
# 0: 384x640 2 persons, 149.3ms
# Speed: 1.9ms preprocess, 149.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 311
#
# 0: 384x640 2 persons, 147.7ms
# Speed: 2.3ms preprocess, 147.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# 312
#
# 0: 384x640 2 persons, 165.3ms
# Speed: 2.5ms preprocess, 165.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 313
#
# 0: 384x640 2 persons, 155.5ms
# Speed: 0.0ms preprocess, 155.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 314
#
# 0: 384x640 2 persons, 136.0ms
# Speed: 8.2ms preprocess, 136.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 315
#
# 0: 384x640 2 persons, 170.8ms
# Speed: 3.0ms preprocess, 170.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 316
#
# 0: 384x640 2 persons, 171.0ms
# Speed: 2.0ms preprocess, 171.0ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# 317
#
# 0: 384x640 2 persons, 144.4ms
# Speed: 1.0ms preprocess, 144.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 318
#
# 0: 384x640 2 persons, 149.8ms
# Speed: 10.8ms preprocess, 149.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 319
#
# 0: 384x640 2 persons, 163.3ms
# Speed: 1.0ms preprocess, 163.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 320
#
# 0: 384x640 2 persons, 158.7ms
# Speed: 4.0ms preprocess, 158.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 321
#
# 0: 384x640 2 persons, 175.4ms
# Speed: 1.9ms preprocess, 175.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 322
#
# 0: 384x640 2 persons, 148.2ms
# Speed: 2.0ms preprocess, 148.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# 323
#
# 0: 384x640 3 persons, 170.2ms
# Speed: 2.1ms preprocess, 170.2ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
# 324
#
# 0: 384x640 2 persons, 148.3ms
# Speed: 0.0ms preprocess, 148.3ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
# 325
#
# 0: 384x640 2 persons, 181.8ms
# Speed: 2.6ms preprocess, 181.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 326
#
# 0: 384x640 2 persons, 189.1ms
# Speed: 4.0ms preprocess, 189.1ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
# 327
#
# 0: 384x640 3 persons, 146.3ms
# Speed: 5.3ms preprocess, 146.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 328
#
# 0: 384x640 3 persons, 132.3ms
# Speed: 2.7ms preprocess, 132.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 329
#
# 0: 384x640 3 persons, 160.7ms
# Speed: 3.0ms preprocess, 160.7ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 330
#
# 0: 384x640 3 persons, 171.4ms
# Speed: 2.0ms preprocess, 171.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 331
#
# 0: 384x640 3 persons, 151.8ms
# Speed: 2.0ms preprocess, 151.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 332
#
# 0: 384x640 3 persons, 168.7ms
# Speed: 3.0ms preprocess, 168.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 333
#
# 0: 384x640 2 persons, 183.4ms
# Speed: 2.0ms preprocess, 183.4ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
# 334
#
# 0: 384x640 2 persons, 170.6ms
# Speed: 2.2ms preprocess, 170.6ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
# 335
#
# 0: 384x640 2 persons, 164.7ms
# Speed: 2.6ms preprocess, 164.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 336
#
# 0: 384x640 2 persons, 152.4ms
# Speed: 2.0ms preprocess, 152.4ms inference, 11.2ms postprocess per image at shape (1, 3, 384, 640)
# 337
#
# 0: 384x640 2 persons, 161.5ms
# Speed: 5.3ms preprocess, 161.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 338
#
# 0: 384x640 3 persons, 180.6ms
# Speed: 1.0ms preprocess, 180.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 339
#
# 0: 384x640 2 persons, 137.1ms
# Speed: 2.0ms preprocess, 137.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# 340
#
# 0: 384x640 3 persons, 186.7ms
# Speed: 0.0ms preprocess, 186.7ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
# 341
#
# 0: 384x640 2 persons, 173.9ms
# Speed: 2.0ms preprocess, 173.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 342
#
# 0: 384x640 2 persons, 138.9ms
# Speed: 2.0ms preprocess, 138.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 343
#
# 0: 384x640 2 persons, 144.7ms
# Speed: 1.7ms preprocess, 144.7ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# 344
#
# 0: 384x640 2 persons, 187.5ms
# Speed: 0.0ms preprocess, 187.5ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# 345
#
# 0: 384x640 2 persons, 171.2ms
# Speed: 2.0ms preprocess, 171.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 346
#
# 0: 384x640 2 persons, 157.9ms
# Speed: 2.0ms preprocess, 157.9ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# 347
#
# 0: 384x640 2 persons, 181.7ms
# Speed: 2.0ms preprocess, 181.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 348
#
# 0: 384x640 2 persons, 157.5ms
# Speed: 2.1ms preprocess, 157.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 349
#
# 0: 384x640 2 persons, 160.1ms
# Speed: 0.0ms preprocess, 160.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 350
#
# 0: 384x640 2 persons, 157.8ms
# Speed: 3.8ms preprocess, 157.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 351
#
# 0: 384x640 2 persons, 177.4ms
# Speed: 0.9ms preprocess, 177.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 352
#
# 0: 384x640 2 persons, 160.5ms
# Speed: 1.7ms preprocess, 160.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# 353
#
# 0: 384x640 1 person, 170.2ms
# Speed: 2.0ms preprocess, 170.2ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# 354
#
# ...
# 12122
#
# 0: 384x640 7 persons, 162.4ms
# Speed: 5.0ms preprocess, 162.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 12123
#
# 0: 384x640 7 persons, 148.2ms
# Speed: 1.9ms preprocess, 148.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 12124
#
# 0: 384x640 7 persons, 136.5ms
# Speed: 3.9ms preprocess, 136.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 12125
#
# 0: 384x640 7 persons, 135.8ms
# Speed: 2.0ms preprocess, 135.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 12126
#
# 0: 384x640 7 persons, 138.2ms
# Speed: 2.0ms preprocess, 138.2ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# 12127
#
# 0: 384x640 7 persons, 138.5ms
# Speed: 2.6ms preprocess, 138.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 12128
#
# 0: 384x640 7 persons, 137.3ms
# Speed: 2.0ms preprocess, 137.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# 12129
#
# 0: 384x640 7 persons, 137.6ms
# Speed: 3.1ms preprocess, 137.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 12130
#
# 0: 384x640 7 persons, 143.7ms
# Speed: 2.0ms preprocess, 143.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 12131
#
# 0: 384x640 8 persons, 143.2ms
# Speed: 2.0ms preprocess, 143.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 12132
#
# 0: 384x640 7 persons, 148.2ms
# Speed: 5.0ms preprocess, 148.2ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# 12133
#
# 0: 384x640 7 persons, 143.0ms
# Speed: 2.1ms preprocess, 143.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# 12134
#
# 0: 384x640 7 persons, 140.2ms
# Speed: 2.0ms preprocess, 140.2ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# 12135
#
# 0: 384x640 7 persons, 140.3ms
# Speed: 3.0ms preprocess, 140.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# 12136
#
# 0: 384x640 7 persons, 137.5ms
# Speed: 2.2ms preprocess, 137.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 12137
#
# 0: 384x640 7 persons, 136.7ms
# Speed: 2.0ms preprocess, 136.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 12138
#
# 0: 384x640 7 persons, 144.5ms
# Speed: 1.9ms preprocess, 144.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 12139
#
# 0: 384x640 7 persons, 147.8ms
# Speed: 2.0ms preprocess, 147.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 12140
#
# 0: 384x640 7 persons, 153.4ms
# Speed: 2.0ms preprocess, 153.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 12141
#
# 0: 384x640 7 persons, 142.5ms
# Speed: 2.0ms preprocess, 142.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 12142
#
# 0: 384x640 7 persons, 140.5ms
# Speed: 3.9ms preprocess, 140.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 12143
#
# 0: 384x640 7 persons, 144.0ms
# Speed: 1.9ms preprocess, 144.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 12144
#
# 0: 384x640 7 persons, 142.4ms
# Speed: 2.6ms preprocess, 142.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 12145
#
# 0: 384x640 7 persons, 133.6ms
# Speed: 4.0ms preprocess, 133.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 12146
#
# 0: 384x640 8 persons, 146.8ms
# Speed: 2.0ms preprocess, 146.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 12147
#
# 0: 384x640 7 persons, 143.9ms
# Speed: 2.0ms preprocess, 143.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 12148
#
# 0: 384x640 7 persons, 1 sports ball, 140.9ms
# Speed: 4.0ms preprocess, 140.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 12149
#
# 0: 384x640 7 persons, 141.1ms
# Speed: 2.0ms preprocess, 141.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 12150
#
# 0: 384x640 7 persons, 143.7ms
# Speed: 1.9ms preprocess, 143.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 12151
#
# 0: 384x640 7 persons, 136.8ms
# Speed: 2.0ms preprocess, 136.8ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 12152
#
# 0: 384x640 7 persons, 149.6ms
# Speed: 3.0ms preprocess, 149.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 12153
#
# 0: 384x640 8 persons, 151.0ms
# Speed: 3.0ms preprocess, 151.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 12154
#
# 0: 384x640 7 persons, 159.1ms
# Speed: 3.0ms preprocess, 159.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 12155
#
# 0: 384x640 8 persons, 135.5ms
# Speed: 5.0ms preprocess, 135.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 12156
#
# 0: 384x640 7 persons, 147.4ms
# Speed: 3.0ms preprocess, 147.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 12157
#
# 0: 384x640 8 persons, 136.2ms
# Speed: 3.5ms preprocess, 136.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 12158
#
# 0: 384x640 7 persons, 138.6ms
# Speed: 2.0ms preprocess, 138.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 12159
#
# 0: 384x640 7 persons, 137.8ms
# Speed: 2.0ms preprocess, 137.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 12160
#
# 0: 384x640 7 persons, 139.5ms
# Speed: 2.0ms preprocess, 139.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 12161
#
# 0: 384x640 7 persons, 144.5ms
# Speed: 2.0ms preprocess, 144.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 12162
#
# 0: 384x640 7 persons, 140.7ms
# Speed: 3.0ms preprocess, 140.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 12163
#
# 0: 384x640 8 persons, 141.5ms
# Speed: 2.0ms preprocess, 141.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 12164
#
# 0: 384x640 8 persons, 139.2ms
# Speed: 2.0ms preprocess, 139.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 12165
#
# 0: 384x640 7 persons, 139.4ms
# Speed: 1.0ms preprocess, 139.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 12166
#
# 0: 384x640 7 persons, 145.1ms
# Speed: 3.0ms preprocess, 145.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 12167
#
# 0: 384x640 8 persons, 137.3ms
# Speed: 1.0ms preprocess, 137.3ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 12168
#
# 0: 384x640 7 persons, 144.5ms
# Speed: 2.0ms preprocess, 144.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 12169
#
# 0: 384x640 7 persons, 135.0ms
# Speed: 2.0ms preprocess, 135.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 12170
#
# 0: 384x640 8 persons, 140.2ms
# Speed: 2.0ms preprocess, 140.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 12171
#
# 0: 384x640 7 persons, 152.6ms
# Speed: 4.0ms preprocess, 152.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 12172
#
# 0: 384x640 7 persons, 143.6ms
# Speed: 2.0ms preprocess, 143.6ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 12173
#
# 0: 384x640 7 persons, 153.7ms
# Speed: 1.9ms preprocess, 153.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Hands UP
# 12174
#
# 0: 384x640 7 persons, 141.4ms
# Speed: 2.0ms preprocess, 141.4ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# 12175
#
# 0: 384x640 7 persons, 142.0ms
# Speed: 3.0ms preprocess, 142.0ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# 12176
#
# 0: 384x640 7 persons, 142.5ms
# Speed: 1.0ms preprocess, 142.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 12177
#
# 0: 384x640 7 persons, 143.9ms
# Speed: 2.0ms preprocess, 143.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 12178
#
# 0: 384x640 7 persons, 151.8ms
# Speed: 2.0ms preprocess, 151.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 12179
#
# 0: 384x640 7 persons, 140.0ms
# Speed: 1.2ms preprocess, 140.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 12180
#
# 0: 384x640 7 persons, 155.1ms
# Speed: 2.0ms preprocess, 155.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 12181
#
# 0: 384x640 7 persons, 136.5ms
# Speed: 3.0ms preprocess, 136.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 12182
#
# 0: 384x640 7 persons, 146.9ms
# Speed: 2.6ms preprocess, 146.9ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
# 12183
#
# 0: 384x640 7 persons, 156.0ms
# Speed: 2.0ms preprocess, 156.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 12184
#
# 0: 384x640 7 persons, 140.9ms
# Speed: 2.0ms preprocess, 140.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 12185
#
# 0: 384x640 7 persons, 135.2ms
# Speed: 2.0ms preprocess, 135.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 12186
#
# 0: 384x640 8 persons, 152.9ms
# Speed: 2.9ms preprocess, 152.9ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# 12187
#
# 0: 384x640 8 persons, 152.1ms
# Speed: 3.0ms preprocess, 152.1ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
# 12188
#
# 0: 384x640 8 persons, 148.0ms
# Speed: 3.0ms preprocess, 148.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 12189
#
# 0: 384x640 8 persons, 142.4ms
# Speed: 5.5ms preprocess, 142.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# 12190
#
# 0: 384x640 8 persons, 161.9ms
# Speed: 2.0ms preprocess, 161.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 12191
#
# 0: 384x640 8 persons, 143.9ms
# Speed: 2.1ms preprocess, 143.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# 12192
#
# 0: 384x640 8 persons, 145.9ms
# Speed: 2.5ms preprocess, 145.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 12193
#
# 0: 384x640 8 persons, 145.1ms
# Speed: 2.0ms preprocess, 145.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 12194
#
# 0: 384x640 7 persons, 143.5ms
# Speed: 1.9ms preprocess, 143.5ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# 12195
#
# 0: 384x640 7 persons, 145.6ms
# Speed: 6.0ms preprocess, 145.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 12196
#
# 0: 384x640 7 persons, 135.0ms
# Speed: 4.0ms preprocess, 135.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 12197
#
# 0: 384x640 7 persons, 141.6ms
# Speed: 3.0ms preprocess, 141.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 12198
#
# 0: 384x640 7 persons, 139.6ms
# Speed: 2.5ms preprocess, 139.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# 12199
#
# 0: 384x640 7 persons, 141.7ms
# Speed: 2.0ms preprocess, 141.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 12200
#
# 0: 384x640 8 persons, 136.7ms
# Speed: 2.0ms preprocess, 136.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 12201
#
# 0: 384x640 8 persons, 145.3ms
# Speed: 2.0ms preprocess, 145.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 12202
#
# 0: 384x640 7 persons, 143.9ms
# Speed: 2.9ms preprocess, 143.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 12203
#
# 0: 384x640 7 persons, 143.1ms
# Speed: 2.1ms preprocess, 143.1ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
# 12204
#
# 0: 384x640 7 persons, 133.5ms
# Speed: 6.0ms preprocess, 133.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 12205
#
# 0: 384x640 7 persons, 142.6ms
# Speed: 4.0ms preprocess, 142.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 12206
#
# 0: 384x640 7 persons, 138.6ms
# Speed: 2.0ms preprocess, 138.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 12207
#
# 0: 384x640 7 persons, 139.2ms
# Speed: 2.9ms preprocess, 139.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 12208
#
# 0: 384x640 7 persons, 138.7ms
# Speed: 3.0ms preprocess, 138.7ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# 12209
#
# 0: 384x640 7 persons, 135.5ms
# Speed: 3.0ms preprocess, 135.5ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# 12210
#
# 0: 384x640 7 persons, 140.0ms
# Speed: 2.0ms preprocess, 140.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 12211
#
# 0: 384x640 7 persons, 129.6ms
# Speed: 3.0ms preprocess, 129.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 12212
#
# 0: 384x640 7 persons, 137.2ms
# Speed: 1.0ms preprocess, 137.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 12213
#
# 0: 384x640 7 persons, 1 tennis racket, 143.5ms
# Speed: 2.0ms preprocess, 143.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 12214
#
# 0: 384x640 7 persons, 151.3ms
# Speed: 2.0ms preprocess, 151.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 12215
#
# 0: 384x640 7 persons, 140.0ms
# Speed: 2.5ms preprocess, 140.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 12216
#
# 0: 384x640 7 persons, 143.6ms
# Speed: 2.5ms preprocess, 143.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 12217
#
# 0: 384x640 7 persons, 137.6ms
# Speed: 1.0ms preprocess, 137.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# 12218
#
# 0: 384x640 8 persons, 145.8ms
# Speed: 2.0ms preprocess, 145.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 12219
#
# 0: 384x640 7 persons, 139.1ms
# Speed: 3.1ms preprocess, 139.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 12220
#
# 0: 384x640 7 persons, 133.5ms
# Speed: 2.0ms preprocess, 133.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 12221
#
# 0: 384x640 7 persons, 1 sports ball, 140.4ms
# Speed: 3.0ms preprocess, 140.4ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# 12222
#
# 0: 384x640 7 persons, 1 sports ball, 155.6ms
# Speed: 2.0ms preprocess, 155.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 12223
#
# 0: 384x640 8 persons, 139.1ms
# Speed: 2.0ms preprocess, 139.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 12224
#
# 0: 384x640 7 persons, 138.7ms
# Speed: 3.9ms preprocess, 138.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 12225
#
# 0: 384x640 7 persons, 147.7ms
# Speed: 2.0ms preprocess, 147.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 12226
#
# 0: 384x640 7 persons, 141.6ms
# Speed: 4.0ms preprocess, 141.6ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# 12227
#
# 0: 384x640 7 persons, 147.2ms
# Speed: 4.0ms preprocess, 147.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 12228
#
# 0: 384x640 7 persons, 165.7ms
# Speed: 2.0ms preprocess, 165.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 12229
#
# 0: 384x640 7 persons, 135.6ms
# Speed: 5.0ms preprocess, 135.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 12230
#
# 0: 384x640 8 persons, 142.7ms
# Speed: 2.0ms preprocess, 142.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 12231
#
# 0: 384x640 8 persons, 1 sports ball, 133.7ms
# Speed: 4.3ms preprocess, 133.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 12232
#
# 0: 384x640 8 persons, 1 sports ball, 137.3ms
# Speed: 4.0ms preprocess, 137.3ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# 12233
#
# 0: 384x640 7 persons, 1 sports ball, 145.3ms
# Speed: 2.0ms preprocess, 145.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 12234
#
# 0: 384x640 8 persons, 1 sports ball, 141.2ms
# Speed: 3.0ms preprocess, 141.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 12235
#
# 0: 384x640 8 persons, 1 sports ball, 141.4ms
# Speed: 2.0ms preprocess, 141.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 12236
#
# 0: 384x640 7 persons, 1 sports ball, 142.1ms
# Speed: 2.0ms preprocess, 142.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 12237

# %%
if __name__== '__main__':
    video_proscessor()

# %%
# import os
# from PIL import Image

# def is_image_corrupted(file_path):
#     try:
#         with Image.open(file_path) as img:
#             img.verify()  # Verify if the image can be opened and is not corrupted
#         return False
#     except (IOError, SyntaxError) as e:
#         return True

# def find_corrupted_files(directory):
#     corrupted_files = []
#     for root, _, files in os.walk(directory):
#         for file in files:
#             file_path = os.path.join(root, file)
#             if is_image_corrupted(file_path):
#                 corrupted_files.append(file_path)
#     return corrupted_files

# def main():
#     directory = input('C:/Users/alimo/OneDrive/Documents/FRT/YOLO MediaPipe Pose Detection/YOLOv8-Mediapipe-Pose-Detection/Output/Hands_Up')
#     corrupted_files = find_corrupted_files(directory)
#     if corrupted_files:
#         print("Corrupted files found:")
#         for file in corrupted_files:
#             print(file)
#     else:
#         print("No corrupted files found.")

# main()

# %%
# # Get the versions
# opencv_version = cv2.__version__
# ultralytics_version = ultralytics.__version__
# mediapipe_version = mp.__version__

# # Write the versions to a requirements.txt file
# with open('/content/drive/MyDrive/bollogy/requirements.txt', 'w') as f:
#     f.write(f"opencv-python=={opencv_version}\n")
#     f.write(f"ultralytics=={ultralytics_version}\n")
#     f.write(f"mediapipe=={mediapipe_version}\n")
#     f.close()

# print("requirements.txt file has been created with the following content:")
# print(f"opencv-python=={opencv_version}")
# print(f"ultralytics=={ultralytics_version}")
# print(f"mediapipe=={mediapipe_version}")
